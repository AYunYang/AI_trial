# %%
#imports
import requests
import json
import pandas as pd
import numpy as np
import warnings
import random
import matplotlib.pyplot as plt
from datetime import datetime
import time as clock

# %%
Sensors_Data = pd.read_json('data/W512_readings.json')
Aircon_Data = pd.read_json('data/W512_aircon_status.json')
Weather_Data = pd.read_json('data/Weather_data.json')

Aircon_Data = Aircon_Data.iloc[3194:]

# Normalize the data
Aircon_rows = []

for _, row in Aircon_Data.iterrows():
    date = row['date']
    time = row['time']
    
    flattened_row = {
        "date": date,
        "time": time
    }
    
    fc_readings = row['FC_FullStatus_Readings']
    
    for unit, data in fc_readings.items():
        if any(data.get("Set_Point", None) == 404.0 for data in fc_readings.values()):
            continue
        flattened_row[f"{unit}_Status"] = data.get("Status", None)
        flattened_row[f"{unit}_Fan_Status"] = data.get("Fan_Status", None)
        flattened_row[f"{unit}_Set_Point"] = data.get("Set_Point", None)
        flattened_row[f"{unit}_Operation_Mode"] = data.get("Operation_Mode", None)
    
    Aircon_rows.append(flattened_row)

Sensors_rows = []
include_keys_1 = ["24E124725E285123", "24E124725E331695","24E124725E331744",
                      "24E124725E332483","24E124725E290348","24E124725E331733","24E124725E286745"]#"24E124136D316361" is suppiosed to be outdoor but it is not outdoor yet
include_keys_2 = ["Sensor_1","Sensor_3","Sensor_6"]
for _, row in Sensors_Data.iterrows():
    invalid_input = False
    
    date = row['date']
    time = row['time']
    
    flattened_row = {
        "date": date,
        "time": time
    }
    
    
    lorawan_readings = row['Lorawan_Readings']
    
    if isinstance(lorawan_readings, dict):
        for unit, data in lorawan_readings.items():
            if unit not in include_keys_1:
                continue
            if isinstance(data, dict):  # Ensure that each item in Lorawan_Readings is a dictionary
                for key, value in data.items():
                    flattened_row[f"{unit}_{key}"] = value
            
    energy_readings = row['Energy_Readings']
    total_power = 0
    total_energy = 0
    invalid_input_power = False
    invalid_input_energy = False
    
    for unit, data in energy_readings.items():
        if unit not in include_keys_2:
            continue
        power = data.get('Power', None)
        energy = data.get('Energy', None)
        if power is None:
            invalid_input_power = True
        if energy is None:
            invalid_input_energy = True
        total_power += power
        total_energy += energy
        
    if invalid_input_power:
        total_power = None
    if invalid_input_energy:
        total_energy = None
        
    flattened_row["Total_Energy"] = total_energy
    flattened_row["Total_Power"] = total_power
    
    Sensors_rows.append(flattened_row)


# Normalize the data
Weather_rows = []

for _, row in Weather_Data.iterrows():
    date = row['date']
    time = row['time']
    
    flattened_row = {
        "date": date,
        "time": time
    }
    
    flattened_row['weather_status']= row['result']['weather_status']
    flattened_row['weather_temp']= row['result']['weather_temp']
    flattened_row['weather_humidity']= row['result']['weather_humidity']
    
    Weather_rows.append(flattened_row)
    
print("Normalizing data")



Aircon_Normalize_Data = pd.DataFrame(Aircon_rows)
Sensors_Normalize_Data = pd.DataFrame(Sensors_rows)
Weather_Normalize_Data = pd.DataFrame(Weather_rows)
# For Aircon_Normalize_Data
Aircon_Normalize_Data['datetime_str'] = Aircon_Normalize_Data['date'].astype(str) + ' ' + Aircon_Normalize_Data['time']
Aircon_Normalize_Data['datetime'] = Aircon_Normalize_Data['datetime_str'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %I:%M:%S %p"))
Aircon_Normalize_Data['timestamp'] = Aircon_Normalize_Data['datetime'].apply(lambda x: int(x.timestamp()))

# For Sensors_Normalize_Data
Sensors_Normalize_Data['datetime_str'] = Sensors_Normalize_Data['date'].astype(str) + ' ' + Sensors_Normalize_Data['time']
Sensors_Normalize_Data['datetime'] = Sensors_Normalize_Data['datetime_str'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %I:%M:%S %p"))
Sensors_Normalize_Data['timestamp'] = Sensors_Normalize_Data['datetime'].apply(lambda x: int(x.timestamp()))

# For Weather_Normalize_Data
Weather_Normalize_Data['datetime_str'] = Weather_Normalize_Data['date'].astype(str) + ' ' + Weather_Normalize_Data['time']
Weather_Normalize_Data['datetime'] = Weather_Normalize_Data['datetime_str'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %I:%M:%S %p"))
Weather_Normalize_Data['timestamp'] = Weather_Normalize_Data['datetime'].apply(lambda x: int(x.timestamp()))

merged_data = pd.merge_asof(
    Aircon_Normalize_Data,  # Left DataFrame
    Sensors_Normalize_Data,      # Right DataFrame
    on='timestamp',   # Key column
    direction='nearest'    # Match the nearest time
)
merged_data = pd.merge_asof(
    merged_data,  # Left DataFrame
    Weather_Normalize_Data,      # Right DataFrame
    on='timestamp',   # Key column
    direction='nearest'    # Match the nearest time
)

temperature_col = [
    col for col in merged_data.columns 
    if "temperature" in col.lower()
]
humidity_col = [
    col for col in merged_data.columns 
    if "humidity" in col.lower()
]

def get_unit_columns(unit_number, columns):
    return [col for col in columns if f"FC_Unit_{unit_number}" in col]

aircon_units = len([
    col for col in merged_data.columns
    if "FC_Unit_" in col and "_Status" in col and "Fan" not in col
])

aircon_units_cols = {}

for unit in range(1, aircon_units + 1):
    aircon_units_cols[f'Unit_{unit}'] = get_unit_columns(unit, merged_data.columns)


final_data = pd.DataFrame()
final_data["timestamp"] = merged_data["timestamp"]

final_data["temperature"] = merged_data[temperature_col].apply(lambda x: round(x.mean(), 3), axis=1)
final_data["humidity"] = merged_data[humidity_col].apply(lambda x: round(x.mean(),3), axis=1)

final_data['power_consumption'] = merged_data['Total_Power']
final_data['energy_consumption'] = merged_data['Total_Energy']

for unit, columns in aircon_units_cols.items():
    for column in columns:
        if 'set_point' in column:
            final_data[column] = merged_data[column].replace(0, pd.NA).ffill()
        else:
            final_data[column] = merged_data[column].replace("ERROR", pd.NA).ffill()

final_data.dropna(inplace=True)
# final_data.reset_index(drop=True, inplace=True)#######################################


final_data.to_csv('final_data_W512_2.csv', index=False)

def getFCData(data, row_index):
    settings = []
    for i in range(1, aircon_units + 1):
        settings.append(data[f"FC_Unit_{i}_Status"].iloc[row_index])
        settings.append(data[f"FC_Unit_{i}_Fan_Status"].iloc[row_index])
        settings.append(data[f"FC_Unit_{i}_Set_Point"].iloc[row_index])
        settings.append(data[f"FC_Unit_{i}_Operation_Mode"].iloc[row_index])
        
    return settings

def is_same_settings(data, curr_row_index, next_row_index):   
    return True if (getFCData(data, curr_row_index) == getFCData(data, next_row_index)) else False


def is_all_off(data, curr_row_index, check_for_off):
    for i in range(1, aircon_units + 1):
        if data[f"FC_Unit_{i}_Status"].iloc[curr_row_index] == "ON":
            return not check_for_off
        
    return check_for_off



aircon_status_result = pd.DataFrame()
total_final_rows = final_data.shape[0]
Aircon_Normalize_Data = Aircon_Normalize_Data.drop(['date', 'time', 'datetime_str', 'datetime', 'timestamp'], axis=1)
for i in range(total_final_rows - 1):
    print(i)
    if is_all_off(final_data, i, True):
        continue

    rows = []
    time_taken = []
    energy_consumption = []
    future_temp = []
    future_humi = []
    
    curr_timestamp = final_data["timestamp"].iloc[i]
    curr_energy = final_data["energy_consumption"].iloc[i]
    curr_temperature = final_data["temperature"].iloc[i]
    curr_humidity = final_data["humidity"].iloc[i]

    
    while i < total_final_rows and is_same_settings(final_data, i + 1, i):
        timetaken = final_data["timestamp"].iloc[i + 1] - curr_timestamp 
        energyConsumption = final_data["energy_consumption"].iloc[i + 1] - curr_energy
        if timetaken < 15 or timetaken > 3600:
            break
        if energyConsumption < 0:
            break
        rows.append(i - 1)
        time_taken.append(timetaken)
        energy_consumption.append(energyConsumption)
        future_temp.append(final_data["temperature"].iloc[i + 1])
        future_humi.append(final_data["humidity"].iloc[i + 1])
        
        i += 1
        
    temp_df = pd.DataFrame({
            'timestamp': [curr_timestamp],
            'rows': [rows],
            'time_taken': [time_taken],
            'energy_consumption': [energy_consumption],
            'future_temp': [future_temp],
            'future_humi': [future_humi],
            'current_temp': [curr_temperature],
            'current_humi': [curr_humidity],
        })
    for col in Aircon_Normalize_Data.columns:
        temp_df[col] = final_data[col].iloc[i]
    
        
    aircon_status_result = pd.concat([aircon_status_result, temp_df], ignore_index=False)        
        
        
        
        
print("Finished")
aircon_status_result = aircon_status_result.sort_values(by=['current_temp'], ascending=False)
aircon_status_result.to_csv('aircon_status_W512_2.csv', index=False)
aircon_status_result.info()
# Out:
# Processing time: 0.36 minutes
# Finished
# <class 'pandas.core.frame.DataFrame'>
# Index: 2323 entries, 0 to 0
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   timestamp                 2323 non-null   int64
#  1   rows                      2323 non-null   object
#  2   time_taken                2323 non-null   object
#  3   energy_consumption        2323 non-null   object
#  4   previous_temp             2323 non-null   object
#  5   previous_humi             2323 non-null   object
#  6   current_temp              2323 non-null   float64
#  7   current_humi              2323 non-null   float64
#  8   FC_Unit_1_Status          2323 non-null   object
#  9   FC_Unit_1_Fan_Status      2323 non-null   object
#  10  FC_Unit_1_Set_Point       2323 non-null   float64
#  11  FC_Unit_1_Operation_Mode  2323 non-null   object
#  12  FC_Unit_2_Status          2323 non-null   object
#  13  FC_Unit_2_Fan_Status      2323 non-null   object
#  14  FC_Unit_2_Set_Point       2323 non-null   float64
#  15  FC_Unit_2_Operation_Mode  2323 non-null   object
#  16  FC_Unit_3_Status          2323 non-null   object
#  17  FC_Unit_3_Fan_Status      2323 non-null   object
#  18  FC_Unit_3_Set_Point       2323 non-null   float64
#  19  FC_Unit_3_Operation_Mode  2323 non-null   object
#  20  FC_Unit_4_Status          2323 non-null   object
#  21  FC_Unit_4_Fan_Status      2323 non-null   object
#  22  FC_Unit_4_Set_Point       2323 non-null   float64
#  23  FC_Unit_4_Operation_Mode  2323 non-null   object
#  24  FC_Unit_5_Status          2323 non-null   object
#  25  FC_Unit_5_Fan_Status      2323 non-null   object
#  26  FC_Unit_5_Set_Point       2323 non-null   float64
#  27  FC_Unit_5_Operation_Mode  2323 non-null   object
#  28  FC_Unit_6_Status          2323 non-null   object
#  29  FC_Unit_6_Fan_Status      2323 non-null   object
#  30  FC_Unit_6_Set_Point       2323 non-null   float64
#  31  FC_Unit_6_Operation_Mode  2323 non-null   object
#  32  FC_Unit_7_Status          2323 non-null   object
#  33  FC_Unit_7_Fan_Status      2323 non-null   object
#  34  FC_Unit_7_Set_Point       2323 non-null   float64
#  35  FC_Unit_7_Operation_Mode  2323 non-null   object
#  36  FC_Unit_8_Status          2323 non-null   object
#  37  FC_Unit_8_Fan_Status      2323 non-null   object
#  38  FC_Unit_8_Set_Point       2323 non-null   float64
#  39  FC_Unit_8_Operation_Mode  2323 non-null   object
# dtypes: float64(10), int64(1), object(29)
# memory usage: 744.1+ KB

# %%
target_temp_range = np.arange(20, 29.5, 0.5)
# target_temp_range = [20]
time_factor = 0.5
energy_factor = 0.5
acceptable_range = 0.2
total_rows = aircon_status_result.shape[0]
stored_dictionary = {}


def getRowData(row_index):
    temperature = aircon_status_result["current_temp"].iloc[row_index]
    humidity = aircon_status_result["current_humi"].iloc[row_index]
    
    return [temperature, humidity]

def getArrayData(row_index, array_index):
    time_taken = aircon_status_result["time_taken"].iloc[row_index]
    energy_consumption = aircon_status_result["energy_consumption"].iloc[row_index]
    temperature = aircon_status_result["future_temp"].iloc[row_index]
    humidity = aircon_status_result["future_humi"].iloc[row_index]
    
    return [temperature[array_index], humidity[array_index], time_taken[array_index], energy_consumption[array_index]]

def comparePath(best_path, current_path):    
    if best_path['factor'] > current_path['factor']:
        return True
    
    return False

# Get heuristic score
h_score = 0
total_score = 0
total_checked = 0
for i in range(total_rows):
    row_data = getRowData(i)
    for j in range(len(aircon_status_result['rows'].iloc[i])):
        array_data = getArrayData(i, j)
        if (abs(row_data[0] - array_data[0]) > 0):
            total_score += ((array_data[3] * energy_factor) + (array_data[2] * time_factor))/(abs(row_data[0] - array_data[0]))
            total_checked += 1
        
h_score = total_score/total_checked
print(h_score)

# h_score is the average amount of energy and time is needed for 1 degree celius
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'future_temp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 37
#      35 row_data = getRowData(i)
#      36 for j in range(len(aircon_status_result['rows'].iloc[i])):
# ---> 37     array_data = getArrayData(i, j)
#      38     if (abs(row_data[0] - array_data[0]) > 0):
#      39         total_score += ((array_data[3] * energy_factor) + (array_data[2] * time_factor))/(abs(row_data[0] - array_data[0]))
#
# Cell In[36], line 19, in getArrayData(row_index, array_index)
#      17 time_taken = aircon_status_result["time_taken"].iloc[row_index]
#      18 energy_consumption = aircon_status_result["energy_consumption"].iloc[row_index]
# ---> 19 temperature = aircon_status_result["future_temp"].iloc[row_index]
#      20 humidity = aircon_status_result["future_humi"].iloc[row_index]
#      22 return [temperature[array_index], humidity[array_index], time_taken[array_index], energy_consumption[array_index]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'future_temp'

# %%
start_time = clock.time()

def calculateScore(array_data):
    return (array_data[3] * energy_factor) + (array_data[2] * time_factor)

def calculateHeuristicScore(start_temp, end_temp):
    return abs(end_temp - start_temp) * h_score

def findMinMax():
    first_temp = aircon_status_result["current_temp"].iloc[0]
    second_temp = aircon_status_result["current_temp"].iloc[total_rows - 1]
    
    ascending = False
    if second_temp > first_temp:
        ascending = True
    
    for i in range(len(aircon_status_result["future_temp"].iloc[total_rows - 1])):
        if ascending:
            second_temp = max(aircon_status_result["future_temp"].iloc[total_rows - 1][i], second_temp)
        else:
            second_temp = min(aircon_status_result["future_temp"].iloc[total_rows - 1][i], second_temp)
    
    return [first_temp, second_temp] if ascending else [second_temp, first_temp]

for target_temp in target_temp_range:
    paths = {}

    
    def AStar(curr_row, curr_arr, checked_nodes):
        # print(curr_row, curr_arr)
        rowData = getRowData(curr_row)
        arrayData = getArrayData(curr_row, curr_arr)
        # Returns the heuristic score and the path
        
        if abs(arrayData[0] - target_temp) < acceptable_range:
            # Scenario 1
            curr_path = {
                'energy_consumption': [arrayData[3]],
                'time_taken': [arrayData[2]],
                'factor': arrayData[3] * energy_factor + arrayData[2] * time_factor,
                'starting_temp': rowData[0],
                'starting_humi': rowData[1],
                'ending_temp': arrayData[0],
                'ending_humi': arrayData[1],
                'path': [curr_row] 
            }
            
            paths[curr_row] = curr_path
            return curr_path['factor'], curr_path
                
        path = {}
        lowestHeuristicScore = float("inf")
        lowestScoreIndex = [-1, -1]
        rowData = getRowData(curr_row)
        
        # A -> B
        # Find B -> C
        # B can be B1, B2, B3, find the best B -> C
        while True:
            out_of_range = False
            for i in range(curr_row + 1, total_rows):
                nextRowData = getRowData(i)
                if checked_nodes[i][0]:
                    continue
                    
                if abs(nextRowData[0] - arrayData[0]) > acceptable_range:
                    if out_of_range:
                        break
                    continue
                
                out_of_range = True
                if i in paths:
                    # if i is already in the path
                    # that means path i is optimized and can be used 
                    heuristicScore = paths[i]['factor']
                    if heuristicScore < lowestHeuristicScore:
                        lowestHeuristicScore = heuristicScore
                        lowestScoreIndex = [i, -1]
                    continue
                    
                for j in range(len(aircon_status_result['rows'].iloc[i])):
                    nextArrayData = getArrayData(i, j)
                    if checked_nodes[i][j + 1]:
                        continue
                    # find the node with the lowest h score
                    heuristicScore = calculateScore(nextArrayData) + calculateHeuristicScore(nextArrayData[0], target_temp)
                    if heuristicScore < lowestHeuristicScore:
                        lowestHeuristicScore = heuristicScore
                        lowestScoreIndex = [i, j]
                        
            if lowestScoreIndex[0] == -1:
                break
                
            if lowestScoreIndex[0] in paths:
                # The shortest path is already found
                # Scenario 1
                if not paths[lowestScoreIndex[0]]["energy_consumption"]:
                    checked_nodes[i][0] = True
                    lowestHeuristicScore = float("inf")
                    lowestScoreIndex = [-1, -1]
                    continue
                    
                path = paths[lowestScoreIndex[0]]
                curr_path = {
                    'energy_consumption': [arrayData[3]] + path['energy_consumption'],
                    'time_taken': [arrayData[2]] + path['time_taken'],
                    'starting_temp': rowData[0],
                    'starting_humi': rowData[1],
                    'ending_temp': path['ending_temp'],
                    'ending_humi': path['ending_humi'],
                    'path': [curr_row] + path['path'] 
                }
                curr_path['factor'] = sum(curr_path['energy_consumption']) * energy_factor + sum(curr_path['time_taken']) * time_factor

                paths[curr_row] = curr_path
                
                return curr_path['factor'], curr_path
            
            if checked_nodes[lowestScoreIndex[0]][lowestScoreIndex[1] + 1]:
                # Scenario 1: the next Node is Valid ( Reaches the target )
                # Scenario 2: all Node in Array is Invalid ( Unable to reach the target )
                # Check if node is valid/invalid
                if lowestHeuristicScore == float("inf"):
                    # Scenario 2
                    paths[curr_row] = {
                        'energy_consumption': [], 
                        'starting_temp': 0, 
                        'starting_humi': 0, 
                        'time_taken': [], 
                        'factor': float('inf'), 
                        'path': []
                    }
                    
                    return float("inf"), paths[curr_row]
                else:
                    # Scenario 1
                    lowestH = min(successful_path.keys())
                    best_path = successful_path[lowestH]
                    
                    curr_path = {
                        'energy_consumption': [arrayData[3]] + best_path['energy_consumption'],
                        'time_taken': [arrayData[2]] + best_path['time_taken'],
                        'starting_temp': rowData[0],
                        'starting_humi': rowData[1],
                        'ending_temp': best_path['ending_temp'],
                        'ending_humi': best_path['ending_humi'],
                        'path': [curr_row] + best_path['path'] 
                    }
                    curr_path['factor'] = sum(curr_path['energy_consumption']) * energy_factor + sum(curr_path['time_taken']) * time_factor
                    
                    paths[curr_row] = curr_path
                    
                return curr_path['factor'], curr_path
            
            # print("Lowest Score Indexex: ", lowestScoreIndex[0], lowestScoreIndex[1])
            # If the path require finding
            checked_nodes[lowestScoreIndex[0]][lowestScoreIndex[1] + 1] = True
            # path returned from AStar is B -> C -> D
            tempScore, path = AStar(lowestScoreIndex[0], lowestScoreIndex[1], checked_nodes)
            lowestHeuristicScore = calculateScore(arrayData) + tempScore
            
            if tempScore != float("inf"):
                successful_path[tempScore] = path
        
        paths[curr_row] = {
            'energy_consumption': [], 
            'starting_temp': 0, 
            'starting_humi': 0, 
            'time_taken': [], 
            'factor': float('inf'), 
            'path': []
        }

        return float('inf'), paths[curr_row]
                
#     minTemp, maxTemp = findMinMax()
#     if target_temp < minTemp or target_temp > maxTemp:
#         continue
    # start_temp = aircon_status_result["current_temp"].iloc[0]
    for i in range(total_rows):
        print(f"jiancong {i}")
        if i not in paths:
            # start A* algorithm for the array
            path = []
            lowestHeuristicScore = float("inf")
            lowestScoreIndex = -1
            rowData = getRowData(i)
            checked_nodes = [False] * len(aircon_status_result['rows'].iloc[i])
            successful_path = {}
            while True:
                for j in range(len(aircon_status_result['rows'].iloc[i])):
                    if checked_nodes[j]:
                        # Skip nodes that are already checked
                        continue

                    arrayData = getArrayData(i, j)
                    # find the node with the lowest h score
                    heuristicScore = calculateScore(arrayData) + calculateHeuristicScore(arrayData[0], target_temp)
                    if heuristicScore < lowestHeuristicScore:
                        lowestHeuristicScore = heuristicScore
                        lowestScoreIndex = j
                
                # print("Current Lowest Index: ", lowestScoreIndex)
                if lowestScoreIndex == -1 or checked_nodes[lowestScoreIndex]:
                    break

                arrayData = getArrayData(i, lowestScoreIndex)
                checked_nodes[lowestScoreIndex] = True
                # path returned from AStar is B -> C -> D
                temp_checked_nodes = [[False] * (len(aircon_status_result['rows'].iloc[i]) + 1) for i in range(total_rows)]
                temp_checked_nodes[i][lowestScoreIndex + 1] = True
                tempScore, path = AStar(i, lowestScoreIndex, temp_checked_nodes)
                lowestHeuristicScore = calculateScore(arrayData) + tempScore
                
            
            
    # print(paths)                    
    # Select the best alternative if no valid paths exist
    if not any(path['factor'] < float('inf') for path in paths.values()):
        print(f"Target temp {target_temp} not achievable, selecting next best value.")
        best_alternative = min(paths.values(), key=lambda p: p['factor'])
        stored_dictionary[f"Dictionary for target temp: {target_temp}"] = best_alternative
    else:
        stored_dictionary[f"Dictionary for target temp: {target_temp}"] = paths.copy()
        
end_time = clock.time()
elapsed_time = end_time - start_time
elapsed_time_minutes = elapsed_time / 60
print(f"Processing time: {elapsed_time_minutes:.2f} minutes")
# Out:
# jiancong 0
# jiancong 1
# jiancong 2
# jiancong 3
# jiancong 4
# jiancong 5
# jiancong 6
# jiancong 7
# jiancong 8
# jiancong 9
# jiancong 10
# jiancong 11
# jiancong 12
# jiancong 13
# jiancong 14
# jiancong 15
# jiancong 16
# jiancong 17
# jiancong 18
# jiancong 19
# jiancong 20
# jiancong 21
# jiancong 22
# jiancong 23
# jiancong 24
# jiancong 25
# jiancong 26
# jiancong 27
# jiancong 28
# jiancong 29
# jiancong 30
# jiancong 31
# jiancong 32
# jiancong 33
# jiancong 34
# jiancong 35
# jiancong 36
# jiancong 37
# jiancong 38
# jiancong 39
# jiancong 40
# jiancong 41
# jiancong 42
# jiancong 43
# jiancong 44
# jiancong 45
# jiancong 46
# jiancong 47
# jiancong 48
# jiancong 49
# jiancong 50
# jiancong 51
# jiancong 52
# jiancong 53
# jiancong 54
# jiancong 55
# jiancong 56
# jiancong 57
# jiancong 58
# jiancong 59
# jiancong 60
# jiancong 61
# jiancong 62
# jiancong 63
# jiancong 64
# jiancong 65
# jiancong 66
# jiancong 67
# jiancong 68
# jiancong 69
# jiancong 70
# jiancong 71
# jiancong 72
# jiancong 73
# jiancong 74
# jiancong 75
# jiancong 76
# jiancong 77
# jiancong 78
# jiancong 79
# jiancong 80
# jiancong 81
# jiancong 82
# jiancong 83
# jiancong 84
# jiancong 85
# jiancong 86
# jiancong 87
# jiancong 88
# jiancong 89
# jiancong 90
# jiancong 91
# jiancong 92
# jiancong 93
# jiancong 94
# jiancong 95
# jiancong 96
# jiancong 97
# jiancong 98
# jiancong 99
# jiancong 100
# jiancong 101
# jiancong 102
# jiancong 103
# jiancong 104
# jiancong 105
# jiancong 106
# jiancong 107
# jiancong 108
# jiancong 109
# jiancong 110
# jiancong 111
# jiancong 112
# jiancong 113
# jiancong 114
# jiancong 115
# jiancong 116
# jiancong 117
# jiancong 118
# jiancong 119
# jiancong 120
# jiancong 121
# jiancong 122
# jiancong 123
# jiancong 124
# jiancong 125
# jiancong 126
# jiancong 127
# jiancong 128
# jiancong 129
# jiancong 130
# jiancong 131
# jiancong 132
# jiancong 133
# jiancong 134
# jiancong 135
# jiancong 136
# jiancong 137
# jiancong 138
# jiancong 139
# jiancong 140
# jiancong 141
# jiancong 142
# jiancong 143
# jiancong 144
# jiancong 145
# jiancong 146
# jiancong 147
# jiancong 148
# jiancong 149
# jiancong 150
# jiancong 151
# jiancong 152
# jiancong 153
# jiancong 154
# jiancong 155
# jiancong 156
# jiancong 157
# jiancong 158
# jiancong 159
# jiancong 160
# jiancong 161
# jiancong 162
# jiancong 163
# jiancong 164
# jiancong 165
# jiancong 166
# jiancong 167
# jiancong 168
# jiancong 169
# jiancong 170
# jiancong 171
# jiancong 172
# jiancong 173
# jiancong 174
# jiancong 175
# jiancong 176
# jiancong 177
# jiancong 178
# jiancong 179
# jiancong 180
# jiancong 181
# jiancong 182
# jiancong 183
# jiancong 184
# jiancong 185
# jiancong 186
# jiancong 187
# jiancong 188
# jiancong 189
# jiancong 190
# jiancong 191
# jiancong 192
# jiancong 193
# jiancong 194
# jiancong 195
# jiancong 196
# jiancong 197
# jiancong 198
# jiancong 199
# jiancong 200
# jiancong 201
# jiancong 202
# jiancong 203
# jiancong 204
# jiancong 205
# jiancong 206
# jiancong 207
# jiancong 208
# jiancong 209
# jiancong 210
# jiancong 211
# jiancong 212
# jiancong 213
# jiancong 214
# jiancong 215
# jiancong 216
# jiancong 217
# jiancong 218
# jiancong 219
# jiancong 220
# jiancong 221
# jiancong 222
# jiancong 223
# jiancong 224
# jiancong 225
# jiancong 226
# jiancong 227
# jiancong 228
# jiancong 229
# jiancong 230
# jiancong 231
# jiancong 232
# jiancong 233
# jiancong 234
# jiancong 235
# jiancong 236
# jiancong 237
# jiancong 238
# jiancong 239
# jiancong 240
# jiancong 241
# jiancong 242
# jiancong 243
# jiancong 244
# jiancong 245
# jiancong 246
# jiancong 247
# jiancong 248
# jiancong 249
# jiancong 250
# jiancong 251
# jiancong 252
# jiancong 253
# jiancong 254
# jiancong 255
# jiancong 256
# jiancong 257
# jiancong 258
# jiancong 259
# jiancong 260
# jiancong 261
# jiancong 262
# jiancong 263
# jiancong 264
# jiancong 265
# jiancong 266
# jiancong 267
# jiancong 268
# jiancong 269
# jiancong 270
# jiancong 271
# jiancong 272
# jiancong 273
# jiancong 274
# jiancong 275
# jiancong 276
# jiancong 277
# jiancong 278
# jiancong 279
# jiancong 280
# jiancong 281
# jiancong 282
# jiancong 283
# jiancong 284
# jiancong 285
# jiancong 286
# jiancong 287
# jiancong 288
# jiancong 289
# jiancong 290
# jiancong 291
# jiancong 292
# jiancong 293
# jiancong 294
# jiancong 295
# jiancong 296
# jiancong 297
# jiancong 298
# jiancong 299
# jiancong 300
# jiancong 301
# jiancong 302
# jiancong 303
# jiancong 304
# jiancong 305
# jiancong 306
# jiancong 307
# jiancong 308
# jiancong 309
# jiancong 310
# jiancong 311
# jiancong 312
# jiancong 313
# jiancong 314
# jiancong 315
# jiancong 316
# jiancong 317
# jiancong 318
# jiancong 319
# jiancong 320
# jiancong 321
# jiancong 322
# jiancong 323
# jiancong 324
# jiancong 325
# jiancong 326
# jiancong 327
# jiancong 328
# jiancong 329
# jiancong 330
# jiancong 331
# jiancong 332
# jiancong 333
# jiancong 334
# jiancong 335
# jiancong 336
# jiancong 337
# jiancong 338
# jiancong 339
# jiancong 340
# jiancong 341
# jiancong 342
# jiancong 343
# jiancong 344
# jiancong 345
# jiancong 346
# jiancong 347
# jiancong 348
# jiancong 349
# jiancong 350
# jiancong 351
# jiancong 352
# jiancong 353
# jiancong 354
# jiancong 355
# jiancong 356
# jiancong 357
# jiancong 358
# jiancong 359
# jiancong 360
# jiancong 361
# jiancong 362
# jiancong 363
# jiancong 364
# jiancong 365
# jiancong 366
# jiancong 367
# jiancong 368
# jiancong 369
# jiancong 370
# jiancong 371
# jiancong 372
# jiancong 373
# jiancong 374
# jiancong 375
# jiancong 376
# jiancong 377
# jiancong 378
# jiancong 379
# jiancong 380
# jiancong 381
# jiancong 382
# jiancong 383
# jiancong 384
# jiancong 385
# jiancong 386
# jiancong 387
# jiancong 388
# jiancong 389
# jiancong 390
# jiancong 391
# jiancong 392
# jiancong 393
# jiancong 394
# jiancong 395
# jiancong 396
# jiancong 397
# jiancong 398
# jiancong 399
# jiancong 400
# jiancong 401
# jiancong 402
# jiancong 403
# jiancong 404
# jiancong 405
# jiancong 406
# jiancong 407
# jiancong 408
# jiancong 409
# jiancong 410
# jiancong 411
# jiancong 412
# jiancong 413
# jiancong 414
# jiancong 415
# jiancong 416
# jiancong 417
# jiancong 418
# jiancong 419
# jiancong 420
# jiancong 421
# jiancong 422
# jiancong 423
# jiancong 424
# jiancong 425
# jiancong 426
# jiancong 427
# jiancong 428
# jiancong 429
# jiancong 430
# jiancong 431
# jiancong 432
# jiancong 433
# jiancong 434
# jiancong 435
# jiancong 436
# jiancong 437
# jiancong 438
# jiancong 439
# jiancong 440
# jiancong 441
# jiancong 442
# jiancong 443
# jiancong 444
# jiancong 445
# jiancong 446
# jiancong 447
# jiancong 448
# jiancong 449
# jiancong 450
# jiancong 451
# jiancong 452
# jiancong 453
# jiancong 454
# jiancong 455
# jiancong 456
# jiancong 457
# jiancong 458
# jiancong 459
# jiancong 460
# jiancong 461
# jiancong 462
# jiancong 463
# jiancong 464
# jiancong 465
# jiancong 466
# jiancong 467
# jiancong 468
# jiancong 469
# jiancong 470
# jiancong 471
# jiancong 472
# jiancong 473
# jiancong 474
# jiancong 475
# jiancong 476
# jiancong 477
# jiancong 478
# jiancong 479
# jiancong 480
# jiancong 481
# jiancong 482
# jiancong 483
# jiancong 484
# jiancong 485
# jiancong 486
# jiancong 487
# jiancong 488
# jiancong 489
# jiancong 490
# jiancong 491
# jiancong 492
# jiancong 493
# jiancong 494
# jiancong 495
# jiancong 496
# jiancong 497
# jiancong 498
# jiancong 499
# jiancong 500
# jiancong 501
# jiancong 502
# jiancong 503
# jiancong 504
# jiancong 505
# jiancong 506
# jiancong 507
# jiancong 508
# jiancong 509
# jiancong 510
# jiancong 511
# jiancong 512
# jiancong 513
# jiancong 514
# jiancong 515
# jiancong 516
# jiancong 517
# jiancong 518
# jiancong 519
# jiancong 520
# jiancong 521
# jiancong 522
# jiancong 523
# jiancong 524
# jiancong 525
# jiancong 526
# jiancong 527
# jiancong 528
# jiancong 529
# jiancong 530
# jiancong 531
# jiancong 532
# jiancong 533
# jiancong 534
# jiancong 535
# jiancong 536
# jiancong 537
# jiancong 538
# jiancong 539
# jiancong 540
# jiancong 541
# jiancong 542
# jiancong 543
# jiancong 544
# jiancong 545
# jiancong 546
# jiancong 547
# jiancong 548
# jiancong 549
# jiancong 550
# jiancong 551
# jiancong 552
# jiancong 553
# jiancong 554
# jiancong 555
# jiancong 556
# jiancong 557
# jiancong 558
# jiancong 559
# jiancong 560
# jiancong 561
# jiancong 562
# jiancong 563
# jiancong 564
# jiancong 565
# jiancong 566
# jiancong 567
# jiancong 568
# jiancong 569
# jiancong 570
# jiancong 571
# jiancong 572
# jiancong 573
# jiancong 574
# jiancong 575
# jiancong 576
# jiancong 577
# jiancong 578
# jiancong 579
# jiancong 580
# jiancong 581
# jiancong 582
# jiancong 583
# jiancong 584
# jiancong 585
# jiancong 586
# jiancong 587
# jiancong 588
# jiancong 589
# jiancong 590
# jiancong 591
# jiancong 592
# jiancong 593
# jiancong 594
# jiancong 595
# jiancong 596
# jiancong 597
# jiancong 598
# jiancong 599
# jiancong 600
# jiancong 601
# jiancong 602
# jiancong 603
# jiancong 604
# jiancong 605
# jiancong 606
# jiancong 607
# jiancong 608
# jiancong 609
# jiancong 610
# jiancong 611
# jiancong 612
# jiancong 613
# jiancong 614
# jiancong 615
# jiancong 616
# jiancong 617
# jiancong 618
# jiancong 619
# jiancong 620
# jiancong 621
# jiancong 622
# jiancong 623
# jiancong 624
# jiancong 625
# jiancong 626
# jiancong 627
# jiancong 628
# jiancong 629
# jiancong 630
# jiancong 631
# jiancong 632
# jiancong 633
# jiancong 634
# jiancong 635
# jiancong 636
# jiancong 637
# jiancong 638
# jiancong 639
# jiancong 640
# jiancong 641
# jiancong 642
# jiancong 643
# jiancong 644
# jiancong 645
# jiancong 646
# jiancong 647
# jiancong 648
# jiancong 649
# jiancong 650
# jiancong 651
# jiancong 652
# jiancong 653
# jiancong 654
# jiancong 655
# jiancong 656
# jiancong 657
# jiancong 658
# jiancong 659
# jiancong 660
# jiancong 661
# jiancong 662
# jiancong 663
# jiancong 664
# jiancong 665
# jiancong 666
# jiancong 667
# jiancong 668
# jiancong 669
# jiancong 670
# jiancong 671
# jiancong 672
# jiancong 673
# jiancong 674
# jiancong 675
# jiancong 676
# jiancong 677
# jiancong 678
# jiancong 679
# jiancong 680
# jiancong 681
# jiancong 682
# jiancong 683
# jiancong 684
# jiancong 685
# jiancong 686
# jiancong 687
# jiancong 688
# jiancong 689
# jiancong 690
# jiancong 691
# jiancong 692
# jiancong 693
# jiancong 694
# jiancong 695
# jiancong 696
# jiancong 697
# jiancong 698
# jiancong 699
# jiancong 700
# jiancong 701
# jiancong 702
# jiancong 703
# jiancong 704
# jiancong 705
# jiancong 706
# jiancong 707
# jiancong 708
# jiancong 709
# jiancong 710
# jiancong 711
# jiancong 712
# jiancong 713
# jiancong 714
# jiancong 715
# jiancong 716
# jiancong 717
# jiancong 718
# jiancong 719
# jiancong 720
# jiancong 721
# jiancong 722
# jiancong 723
# jiancong 724
# jiancong 725
# jiancong 726
# jiancong 727
# jiancong 728
# jiancong 729
# jiancong 730
# jiancong 731
# jiancong 732
# jiancong 733
# jiancong 734
# jiancong 735
# jiancong 736
# jiancong 737
# jiancong 738
# jiancong 739
# jiancong 740
# jiancong 741
# jiancong 742
# jiancong 743
# jiancong 744
# jiancong 745
# jiancong 746
# jiancong 747
# jiancong 748
# jiancong 749
# jiancong 750
# jiancong 751
# jiancong 752
# jiancong 753
# jiancong 754
# jiancong 755
# jiancong 756
# jiancong 757
# jiancong 758
# jiancong 759
# jiancong 760
# jiancong 761
# jiancong 762
# jiancong 763
# jiancong 764
# jiancong 765
# jiancong 766
# jiancong 767
# jiancong 768
# jiancong 769
# jiancong 770
# jiancong 771
# jiancong 772
# jiancong 773
# jiancong 774
# jiancong 775
# jiancong 776
# jiancong 777
# jiancong 778
# jiancong 779
# jiancong 780
# jiancong 781
# jiancong 782
# jiancong 783
# jiancong 784
# jiancong 785
# jiancong 786
# jiancong 787
# jiancong 788
# jiancong 789
# jiancong 790
# jiancong 791
# jiancong 792
# jiancong 793
# jiancong 794
# jiancong 795
# jiancong 796
# jiancong 797
# jiancong 798
# jiancong 799
# jiancong 800
# jiancong 801
# jiancong 802
# jiancong 803
# jiancong 804
# jiancong 805
# jiancong 806
# jiancong 807
# jiancong 808
# jiancong 809
# jiancong 810
# jiancong 811
# jiancong 812
# jiancong 813
# jiancong 814
# jiancong 815
# jiancong 816
# jiancong 817
# jiancong 818
# jiancong 819
# jiancong 820
# jiancong 821
# jiancong 822
# jiancong 823
# jiancong 824
# jiancong 825
# jiancong 826
# jiancong 827
# jiancong 828
# jiancong 829
# jiancong 830
# jiancong 831
# jiancong 832
# jiancong 833
# jiancong 834
# jiancong 835
# jiancong 836
# jiancong 837
# jiancong 838
# jiancong 839
# jiancong 840
# jiancong 841
# jiancong 842
# jiancong 843
# jiancong 844
# jiancong 845
# jiancong 846
# jiancong 847
# jiancong 848
# jiancong 849
# jiancong 850
# jiancong 851
# jiancong 852
# jiancong 853
# jiancong 854
# jiancong 855
# jiancong 856
# jiancong 857
# jiancong 858
# jiancong 859
# jiancong 860
# jiancong 861
# jiancong 862
# jiancong 863
# jiancong 864
# jiancong 865
# jiancong 866
# jiancong 867
# jiancong 868
# jiancong 869
# jiancong 870
# jiancong 871
# jiancong 872
# jiancong 873
# jiancong 874
# jiancong 875
# jiancong 876
# jiancong 877
# jiancong 878
# jiancong 879
# jiancong 880
# jiancong 881
# jiancong 882
# jiancong 883
# jiancong 884
# jiancong 885
# jiancong 886
# jiancong 887
# jiancong 888
# jiancong 889
# jiancong 890
# jiancong 891
# jiancong 892
# jiancong 893
# jiancong 894
# jiancong 895
# jiancong 896
# jiancong 897
# jiancong 898
# jiancong 899
# jiancong 900
# jiancong 901
# jiancong 902
# jiancong 903
# jiancong 904
# jiancong 905
# jiancong 906
# jiancong 907
# jiancong 908
# jiancong 909
# jiancong 910
# jiancong 911
# jiancong 912
# jiancong 913
# jiancong 914
# jiancong 915
# jiancong 916
# jiancong 917
# jiancong 918
# jiancong 919
# jiancong 920
# jiancong 921
# jiancong 922
# jiancong 923
# jiancong 924
# jiancong 925
# jiancong 926
# jiancong 927
# jiancong 928
# jiancong 929
# jiancong 930
# jiancong 931
# jiancong 932
# jiancong 933
# jiancong 934
# jiancong 935
# jiancong 936
# jiancong 937
# jiancong 938
# jiancong 939
# jiancong 940
# jiancong 941
# jiancong 942
# jiancong 943
# jiancong 944
# jiancong 945
# jiancong 946
# jiancong 947
# jiancong 948
# jiancong 949
# jiancong 950
# jiancong 951
# jiancong 952
# jiancong 953
# jiancong 954
# jiancong 955
# jiancong 956
# jiancong 957
# jiancong 958
# jiancong 959
# jiancong 960
# jiancong 961
# jiancong 962
# jiancong 963
# jiancong 964
# jiancong 965
# jiancong 966
# jiancong 967
# jiancong 968
# jiancong 969
# jiancong 970
# jiancong 971
# jiancong 972
# jiancong 973
# jiancong 974
# jiancong 975
# jiancong 976
# jiancong 977
# jiancong 978
# jiancong 979
# jiancong 980
# jiancong 981
# jiancong 982
# jiancong 983
# jiancong 984
# jiancong 985
# jiancong 986
# jiancong 987
# jiancong 988
# jiancong 989
# jiancong 990
# jiancong 991
# jiancong 992
# jiancong 993
# jiancong 994
# jiancong 995
# jiancong 996
# jiancong 997
# jiancong 998
# jiancong 999
# jiancong 1000
# jiancong 1001
# jiancong 1002
# jiancong 1003
# jiancong 1004
# jiancong 1005
# jiancong 1006
# jiancong 1007
# jiancong 1008
# jiancong 1009
# jiancong 1010
# jiancong 1011
# jiancong 1012
# jiancong 1013
# jiancong 1014
# jiancong 1015
# jiancong 1016
# jiancong 1017
# jiancong 1018
# jiancong 1019
# jiancong 1020
# jiancong 1021
# jiancong 1022
# jiancong 1023
# jiancong 1024
# jiancong 1025
# jiancong 1026
# jiancong 1027
# jiancong 1028
# jiancong 1029
# jiancong 1030
# jiancong 1031
# jiancong 1032
# jiancong 1033
# jiancong 1034
# jiancong 1035
# jiancong 1036
# jiancong 1037
# jiancong 1038
# jiancong 1039
# jiancong 1040
# jiancong 1041
# jiancong 1042
# jiancong 1043
# jiancong 1044
# jiancong 1045
# jiancong 1046
# jiancong 1047
# jiancong 1048
# jiancong 1049
# jiancong 1050
# jiancong 1051
# jiancong 1052
# jiancong 1053
# jiancong 1054
# jiancong 1055
# jiancong 1056
# jiancong 1057
# jiancong 1058
# jiancong 1059
# jiancong 1060
# jiancong 1061
# jiancong 1062
# jiancong 1063
# jiancong 1064
# jiancong 1065
# jiancong 1066
# jiancong 1067
# jiancong 1068
# jiancong 1069
# jiancong 1070
# jiancong 1071
# jiancong 1072
# jiancong 1073
# jiancong 1074
# jiancong 1075
# jiancong 1076
# jiancong 1077
# jiancong 1078
# jiancong 1079
# jiancong 1080
# jiancong 1081
# jiancong 1082
# jiancong 1083
# jiancong 1084
# jiancong 1085
# jiancong 1086
# jiancong 1087
# jiancong 1088
# jiancong 1089
# jiancong 1090
# jiancong 1091
# jiancong 1092
# jiancong 1093
# jiancong 1094
# jiancong 1095
# jiancong 1096
# jiancong 1097
# jiancong 1098
# jiancong 1099
# jiancong 1100
# jiancong 1101
# jiancong 1102
# jiancong 1103
# jiancong 1104
# jiancong 1105
# jiancong 1106
# jiancong 1107
# jiancong 1108
# jiancong 1109
# jiancong 1110
# jiancong 1111
# jiancong 1112
# jiancong 1113
# jiancong 1114
# jiancong 1115
# jiancong 1116
# jiancong 1117
# jiancong 1118
# jiancong 1119
# jiancong 1120
# jiancong 1121
# jiancong 1122
# jiancong 1123
# jiancong 1124
# jiancong 1125
# jiancong 1126
# jiancong 1127
# jiancong 1128
# jiancong 1129
# jiancong 1130
# jiancong 1131
# jiancong 1132
# jiancong 1133
# jiancong 1134
# jiancong 1135
# jiancong 1136
# jiancong 1137
# jiancong 1138
# jiancong 1139
# jiancong 1140
# jiancong 1141
# jiancong 1142
# jiancong 1143
# jiancong 1144
# jiancong 1145
# jiancong 1146
# jiancong 1147
# jiancong 1148
# jiancong 1149
# jiancong 1150
# jiancong 1151
# jiancong 1152
# jiancong 1153
# jiancong 1154
# jiancong 1155
# jiancong 1156
# jiancong 1157
# jiancong 1158
# jiancong 1159
# jiancong 1160
# jiancong 1161
# jiancong 1162
# jiancong 1163
# jiancong 1164
# jiancong 1165
# jiancong 1166
# jiancong 1167
# jiancong 1168
# jiancong 1169
# jiancong 1170
# jiancong 1171
# jiancong 1172
# jiancong 1173
# jiancong 1174
# jiancong 1175
# jiancong 1176
# jiancong 1177
# jiancong 1178
# jiancong 1179
# jiancong 1180
# jiancong 1181
# jiancong 1182
# jiancong 1183
# jiancong 1184
# jiancong 1185
# jiancong 1186
# jiancong 1187
# jiancong 1188
# jiancong 1189
# jiancong 1190
# jiancong 1191
# jiancong 1192
# jiancong 1193
# jiancong 1194
# jiancong 1195
# jiancong 1196
# jiancong 1197
# jiancong 1198
# jiancong 1199
# jiancong 1200
# jiancong 1201
# jiancong 1202
# jiancong 1203
# jiancong 1204
# jiancong 1205
# jiancong 1206
# jiancong 1207
# jiancong 1208
# jiancong 1209
# jiancong 1210
# jiancong 1211
# jiancong 1212
# jiancong 1213
# jiancong 1214
# jiancong 1215
# jiancong 1216
# jiancong 1217
# jiancong 1218
# jiancong 1219
# jiancong 1220
# jiancong 1221
# jiancong 1222
# jiancong 1223
# jiancong 1224
# jiancong 1225
# jiancong 1226
# jiancong 1227
# jiancong 1228
# jiancong 1229
# jiancong 1230
# jiancong 1231
# jiancong 1232
# jiancong 1233
# jiancong 1234
# jiancong 1235
# jiancong 1236
# jiancong 1237
# jiancong 1238
# jiancong 1239
# jiancong 1240
# jiancong 1241
# jiancong 1242
# jiancong 1243
# jiancong 1244
# jiancong 1245
# jiancong 1246
# jiancong 1247
# jiancong 1248
# jiancong 1249
# jiancong 1250
# jiancong 1251
# jiancong 1252
# jiancong 1253
# jiancong 1254
# jiancong 1255
# jiancong 1256
# jiancong 1257
# jiancong 1258
# jiancong 1259
# jiancong 1260
# jiancong 1261
# jiancong 1262
# jiancong 1263
# jiancong 1264
# jiancong 1265
# jiancong 1266
# jiancong 1267
# jiancong 1268
# jiancong 1269
# jiancong 1270
# jiancong 1271
# jiancong 1272
# jiancong 1273
# jiancong 1274
# jiancong 1275
# jiancong 1276
# jiancong 1277
# jiancong 1278
# jiancong 1279
# jiancong 1280
# jiancong 1281
# jiancong 1282
# jiancong 1283
# jiancong 1284
# jiancong 1285
# jiancong 1286
# jiancong 1287
# jiancong 1288
# jiancong 1289
# jiancong 1290
# jiancong 1291
# jiancong 1292
# jiancong 1293
# jiancong 1294
# jiancong 1295
# jiancong 1296
# jiancong 1297
# jiancong 1298
# jiancong 1299
# jiancong 1300
# jiancong 1301
# jiancong 1302
# jiancong 1303
# jiancong 1304
# jiancong 1305
# jiancong 1306
# jiancong 1307
# jiancong 1308
# jiancong 1309
# jiancong 1310
# jiancong 1311
# jiancong 1312
# jiancong 1313
# jiancong 1314
# jiancong 1315
# jiancong 1316
# jiancong 1317
# jiancong 1318
# jiancong 1319
# jiancong 1320
# jiancong 1321
# jiancong 1322
# jiancong 1323
# jiancong 1324
# jiancong 1325
# jiancong 1326
# jiancong 1327
# jiancong 1328
# jiancong 1329
# jiancong 1330
# jiancong 1331
# jiancong 1332
# jiancong 1333
# jiancong 1334
# jiancong 1335
# jiancong 1336
# jiancong 1337
# jiancong 1338
# jiancong 1339
# jiancong 1340
# jiancong 1341
# jiancong 1342
# jiancong 1343
# jiancong 1344
# jiancong 1345
# jiancong 1346
# jiancong 1347
# jiancong 1348
# jiancong 1349
# jiancong 1350
# jiancong 1351
# jiancong 1352
# jiancong 1353
# jiancong 1354
# jiancong 1355
# jiancong 1356
# jiancong 1357
# jiancong 1358
# jiancong 1359
# jiancong 1360
# jiancong 1361
# jiancong 1362
# jiancong 1363
# jiancong 1364
# jiancong 1365
# jiancong 1366
# jiancong 1367
# jiancong 1368
# jiancong 1369
# jiancong 1370
# jiancong 1371
# jiancong 1372
# jiancong 1373
# jiancong 1374
# jiancong 1375
# jiancong 1376
# jiancong 1377
# jiancong 1378
# jiancong 1379
# jiancong 1380
# jiancong 1381
# jiancong 1382
# jiancong 1383
# jiancong 1384
# jiancong 1385
# jiancong 1386
# jiancong 1387
# jiancong 1388
# jiancong 1389
# jiancong 1390
# jiancong 1391
# jiancong 1392
# jiancong 1393
# jiancong 1394
# jiancong 1395
# jiancong 1396
# jiancong 1397
# jiancong 1398
# jiancong 1399
# jiancong 1400
# jiancong 1401
# jiancong 1402
# jiancong 1403
# jiancong 1404
# jiancong 1405
# jiancong 1406
# jiancong 1407
# jiancong 1408
# jiancong 1409
# jiancong 1410
# jiancong 1411
# jiancong 1412
# jiancong 1413
# jiancong 1414
# jiancong 1415
# jiancong 1416
# jiancong 1417
# jiancong 1418
# jiancong 1419
# jiancong 1420
# jiancong 1421
# jiancong 1422
# jiancong 1423
# jiancong 1424
# jiancong 1425
# jiancong 1426
# jiancong 1427
# jiancong 1428
# jiancong 1429
# jiancong 1430
# jiancong 1431
# jiancong 1432
# jiancong 1433
# jiancong 1434
# jiancong 1435
# jiancong 1436
# jiancong 1437
# jiancong 1438
# jiancong 1439
# jiancong 1440
# jiancong 1441
# jiancong 1442
# jiancong 1443
# jiancong 1444
# jiancong 1445
# jiancong 1446
# jiancong 1447
# jiancong 1448
# jiancong 1449
# jiancong 1450
# jiancong 1451
# jiancong 1452
# jiancong 1453
# jiancong 1454
# jiancong 1455
# jiancong 1456
# jiancong 1457
# jiancong 1458
# jiancong 1459
# jiancong 1460
# jiancong 1461
# jiancong 1462
# jiancong 1463
# jiancong 1464
# jiancong 1465
# jiancong 1466
# jiancong 1467
# jiancong 1468
# jiancong 1469
# jiancong 1470
# jiancong 1471
# jiancong 1472
# jiancong 1473
# jiancong 1474
# jiancong 1475
# jiancong 1476
# jiancong 1477
# jiancong 1478
# jiancong 1479
# jiancong 1480
# jiancong 1481
# jiancong 1482
# jiancong 1483
# jiancong 1484
# jiancong 1485
# jiancong 1486
# jiancong 1487
# jiancong 1488
# jiancong 1489
# jiancong 1490
# jiancong 1491
# jiancong 1492
# jiancong 1493
# jiancong 1494
# jiancong 1495
# jiancong 1496
# jiancong 1497
# jiancong 1498
# jiancong 1499
# jiancong 1500
# jiancong 1501
# jiancong 1502
# jiancong 1503
# jiancong 1504
# jiancong 1505
# jiancong 1506
# jiancong 1507
# jiancong 1508
# jiancong 1509
# jiancong 1510
# jiancong 1511
# jiancong 1512
# jiancong 1513
# jiancong 1514
# jiancong 1515
# jiancong 1516
# jiancong 1517
# jiancong 1518
# jiancong 1519
# jiancong 1520
# jiancong 1521
# jiancong 1522
# jiancong 1523
# jiancong 1524
# jiancong 1525
# jiancong 1526
# jiancong 1527
# jiancong 1528
# jiancong 1529
# jiancong 1530
# jiancong 1531
# jiancong 1532
# jiancong 1533
# jiancong 1534
# jiancong 1535
# jiancong 1536
# jiancong 1537
# jiancong 1538
# jiancong 1539
# jiancong 1540
# jiancong 1541
# jiancong 1542
# jiancong 1543
# jiancong 1544
# jiancong 1545
# jiancong 1546
# jiancong 1547
# jiancong 1548
# jiancong 1549
# jiancong 1550
# jiancong 1551
# jiancong 1552
# jiancong 1553
# jiancong 1554
# jiancong 1555
# jiancong 1556
# jiancong 1557
# jiancong 1558
# jiancong 1559
# jiancong 1560
# jiancong 1561
# jiancong 1562
# jiancong 1563
# jiancong 1564
# jiancong 1565
# jiancong 1566
# jiancong 1567
# jiancong 1568
# jiancong 1569
# jiancong 1570
# jiancong 1571
# jiancong 1572
# jiancong 1573
# jiancong 1574
# jiancong 1575
# jiancong 1576
# jiancong 1577
# jiancong 1578
# jiancong 1579
# jiancong 1580
# jiancong 1581
# jiancong 1582
# jiancong 1583
# jiancong 1584
# jiancong 1585
# jiancong 1586
# jiancong 1587
# jiancong 1588
# jiancong 1589
# jiancong 1590
# jiancong 1591
# jiancong 1592
# jiancong 1593
# jiancong 1594
# jiancong 1595
# jiancong 1596
# jiancong 1597
# jiancong 1598
# jiancong 1599
# jiancong 1600
# jiancong 1601
# jiancong 1602
# jiancong 1603
# jiancong 1604
# jiancong 1605
# jiancong 1606
# jiancong 1607
# jiancong 1608
# jiancong 1609
# jiancong 1610
# jiancong 1611
# jiancong 1612
# jiancong 1613
# jiancong 1614
# jiancong 1615
# jiancong 1616
# jiancong 1617
# jiancong 1618
# jiancong 1619
# jiancong 1620
# jiancong 1621
# jiancong 1622
# jiancong 1623
# jiancong 1624
# jiancong 1625
# jiancong 1626
# jiancong 1627
# jiancong 1628
# jiancong 1629
# jiancong 1630
# jiancong 1631
# jiancong 1632
# jiancong 1633
# jiancong 1634
# jiancong 1635
# jiancong 1636
# jiancong 1637
# jiancong 1638
# jiancong 1639
# jiancong 1640
# jiancong 1641
# jiancong 1642
# jiancong 1643
# jiancong 1644
# jiancong 1645
# jiancong 1646
# jiancong 1647
# jiancong 1648
# jiancong 1649
# jiancong 1650
# jiancong 1651
# jiancong 1652
# jiancong 1653
# jiancong 1654
# jiancong 1655
# jiancong 1656
# jiancong 1657
# jiancong 1658
# jiancong 1659
# jiancong 1660
# jiancong 1661
# jiancong 1662
# jiancong 1663
# jiancong 1664
# jiancong 1665
# jiancong 1666
# jiancong 1667
# jiancong 1668
# jiancong 1669
# jiancong 1670
# jiancong 1671
# jiancong 1672
# jiancong 1673
# jiancong 1674
# jiancong 1675
# jiancong 1676
# jiancong 1677
# jiancong 1678
# jiancong 1679
# jiancong 1680
# jiancong 1681
# jiancong 1682
# jiancong 1683
# jiancong 1684
# jiancong 1685
# jiancong 1686
# jiancong 1687
# jiancong 1688
# jiancong 1689
# jiancong 1690
# jiancong 1691
# jiancong 1692
# jiancong 1693
# jiancong 1694
# jiancong 1695
# jiancong 1696
# jiancong 1697
# jiancong 1698
# jiancong 1699
# jiancong 1700
# jiancong 1701
# jiancong 1702
# jiancong 1703
# jiancong 1704
# jiancong 1705
# jiancong 1706
# jiancong 1707
# jiancong 1708
# jiancong 1709
# jiancong 1710
# jiancong 1711
# jiancong 1712
# jiancong 1713
# jiancong 1714
# jiancong 1715
# jiancong 1716
# jiancong 1717
# jiancong 1718
# jiancong 1719
# jiancong 1720
# jiancong 1721
# jiancong 1722
# jiancong 1723
# jiancong 1724
# jiancong 1725
# jiancong 1726
# jiancong 1727
# jiancong 1728
# jiancong 1729
# jiancong 1730
# jiancong 1731
# jiancong 1732
# jiancong 1733
# jiancong 1734
# jiancong 1735
# jiancong 1736
# jiancong 1737
# jiancong 1738
# jiancong 1739
# jiancong 1740
# jiancong 1741
# jiancong 1742
# jiancong 1743
# jiancong 1744
# jiancong 1745
# jiancong 1746
# jiancong 1747
# jiancong 1748
# jiancong 1749
# jiancong 1750
# jiancong 1751
# jiancong 1752
# jiancong 1753
# jiancong 1754
# jiancong 1755
# jiancong 1756
# jiancong 1757
# jiancong 1758
# jiancong 1759
# jiancong 1760
# jiancong 1761
# jiancong 1762
# jiancong 1763
# jiancong 1764
# jiancong 1765
# jiancong 1766
# jiancong 1767
# jiancong 1768
# jiancong 1769
# jiancong 1770
# jiancong 1771
# jiancong 1772
# jiancong 1773
# jiancong 1774
# jiancong 1775
# jiancong 1776
# jiancong 1777
# jiancong 1778
# jiancong 1779
# jiancong 1780
# jiancong 1781
# jiancong 1782
# jiancong 1783
# jiancong 1784
# jiancong 1785
# jiancong 1786
# jiancong 1787
# jiancong 1788
# jiancong 1789
# jiancong 1790
# jiancong 1791
# jiancong 1792
# jiancong 1793
# jiancong 1794
# jiancong 1795
# jiancong 1796
# jiancong 1797
# jiancong 1798
# jiancong 1799
# jiancong 1800
# jiancong 1801
# jiancong 1802
# jiancong 1803
# jiancong 1804
# jiancong 1805
# jiancong 1806
# jiancong 1807
# jiancong 1808
# jiancong 1809
# jiancong 1810
# jiancong 1811
# jiancong 1812
# jiancong 1813
# jiancong 1814
# jiancong 1815
# jiancong 1816
# jiancong 1817
# jiancong 1818
# jiancong 1819
# jiancong 1820
# jiancong 1821
# jiancong 1822
# jiancong 1823
# jiancong 1824
# jiancong 1825
# jiancong 1826
# jiancong 1827
# jiancong 1828
# jiancong 1829
# jiancong 1830
# jiancong 1831
# jiancong 1832
# jiancong 1833
# jiancong 1834
# jiancong 1835
# jiancong 1836
# jiancong 1837
# jiancong 1838
# jiancong 1839
# jiancong 1840
# jiancong 1841
# jiancong 1842
# jiancong 1843
# jiancong 1844
# jiancong 1845
# jiancong 1846
# jiancong 1847
# jiancong 1848
# jiancong 1849
# jiancong 1850
# jiancong 1851
# jiancong 1852
# jiancong 1853
# jiancong 1854
# jiancong 1855
# jiancong 1856
# jiancong 1857
# jiancong 1858
# jiancong 1859
# jiancong 1860
# jiancong 1861
# jiancong 1862
# jiancong 1863
# jiancong 1864
# jiancong 1865
# jiancong 1866
# jiancong 1867
# jiancong 1868
# jiancong 1869
# jiancong 1870
# jiancong 1871
# jiancong 1872
# jiancong 1873
# jiancong 1874
# jiancong 1875
# jiancong 1876
# jiancong 1877
# jiancong 1878
# jiancong 1879
# jiancong 1880
# jiancong 1881
# jiancong 1882
# jiancong 1883
# jiancong 1884
# jiancong 1885
# jiancong 1886
# jiancong 1887
# jiancong 1888
# jiancong 1889
# jiancong 1890
# jiancong 1891
# jiancong 1892
# jiancong 1893
# jiancong 1894
# jiancong 1895
# jiancong 1896
# jiancong 1897
# jiancong 1898
# jiancong 1899
# jiancong 1900
# jiancong 1901
# jiancong 1902
# jiancong 1903
# jiancong 1904
# jiancong 1905
# jiancong 1906
# jiancong 1907
# jiancong 1908
# jiancong 1909
# jiancong 1910
# jiancong 1911
# jiancong 1912
# jiancong 1913
# jiancong 1914
# jiancong 1915
# jiancong 1916
# jiancong 1917
# jiancong 1918
# jiancong 1919
# jiancong 1920
# jiancong 1921
# jiancong 1922
# jiancong 1923
# jiancong 1924
# jiancong 1925
# jiancong 1926
# jiancong 1927
# jiancong 1928
# jiancong 1929
# jiancong 1930
# jiancong 1931
# jiancong 1932
# jiancong 1933
# jiancong 1934
# jiancong 1935
# jiancong 1936
# jiancong 1937
# jiancong 1938
# jiancong 1939
# jiancong 1940
# jiancong 1941
# jiancong 1942
# jiancong 1943
# jiancong 1944
# jiancong 1945
# jiancong 1946
# jiancong 1947
# jiancong 1948
# jiancong 1949
# jiancong 1950
# jiancong 1951
# jiancong 1952
# jiancong 1953
# jiancong 1954
# jiancong 1955
# jiancong 1956
# jiancong 1957
# jiancong 1958
# jiancong 1959
# jiancong 1960
# jiancong 1961
# jiancong 1962
# jiancong 1963
# jiancong 1964
# jiancong 1965
# jiancong 1966
# jiancong 1967
# jiancong 1968
# jiancong 1969
# jiancong 1970
# jiancong 1971
# jiancong 1972
# jiancong 1973
# jiancong 1974
# jiancong 1975
# jiancong 1976
# jiancong 1977
# jiancong 1978
# jiancong 1979
# jiancong 1980
# jiancong 1981
# jiancong 1982
# jiancong 1983
# jiancong 1984
# jiancong 1985
# jiancong 1986
# jiancong 1987
# jiancong 1988
# jiancong 1989
# jiancong 1990
# jiancong 1991
# jiancong 1992
# jiancong 1993
# jiancong 1994
# jiancong 1995
# jiancong 1996
# jiancong 1997
# jiancong 1998
# jiancong 1999
# jiancong 2000
# jiancong 2001
# jiancong 2002
# jiancong 2003
# jiancong 2004
# jiancong 2005
# jiancong 2006
# jiancong 2007
# jiancong 2008
# jiancong 2009
# jiancong 2010
# jiancong 2011
# jiancong 2012
# jiancong 2013
# jiancong 2014
# jiancong 2015
# jiancong 2016
# jiancong 2017
# jiancong 2018
# jiancong 2019
# jiancong 2020
# jiancong 2021
# jiancong 2022
# jiancong 2023
# jiancong 2024
# jiancong 2025
# jiancong 2026
# jiancong 2027
# jiancong 2028
# jiancong 2029
# jiancong 2030
# jiancong 2031
# jiancong 2032
# jiancong 2033
# jiancong 2034
# jiancong 2035
# jiancong 2036
# jiancong 2037
# jiancong 2038
# jiancong 2039
# jiancong 2040
# jiancong 2041
# jiancong 2042
# jiancong 2043
# jiancong 2044
# jiancong 2045
# jiancong 2046
# jiancong 2047
# jiancong 2048
# jiancong 2049
# jiancong 2050
# jiancong 2051
# jiancong 2052
# jiancong 2053
# jiancong 2054
# jiancong 2055
# jiancong 2056
# jiancong 2057
# jiancong 2058
# jiancong 2059
# jiancong 2060
# jiancong 2061
# jiancong 2062
# jiancong 2063
# jiancong 2064
# jiancong 2065
# jiancong 2066
# jiancong 2067
# jiancong 2068
# jiancong 2069
# jiancong 2070
# jiancong 2071
# jiancong 2072
# jiancong 2073
# jiancong 2074
# jiancong 2075
# jiancong 2076
# jiancong 2077
# jiancong 2078
# jiancong 2079
# jiancong 2080
# jiancong 2081
# jiancong 2082
# jiancong 2083
# jiancong 2084
# jiancong 2085
# jiancong 2086
# jiancong 2087
# jiancong 2088
# jiancong 2089
# jiancong 2090
# jiancong 2091
# jiancong 2092
# jiancong 2093
# jiancong 2094
# jiancong 2095
# jiancong 2096
# jiancong 2097
# jiancong 2098
# jiancong 2099
# jiancong 2100
# jiancong 2101
# jiancong 2102
# jiancong 2103
# jiancong 2104
# jiancong 2105
# jiancong 2106
# jiancong 2107
# jiancong 2108
# jiancong 2109
# jiancong 2110
# jiancong 2111
# jiancong 2112
# jiancong 2113
# jiancong 2114
# jiancong 2115
# jiancong 2116
# jiancong 2117
# jiancong 2118
# jiancong 2119
# jiancong 2120
# jiancong 2121
# jiancong 2122
# jiancong 2123
# jiancong 2124
# jiancong 2125
# jiancong 2126
# jiancong 2127
# jiancong 2128
# jiancong 2129
# jiancong 2130
# jiancong 2131
# jiancong 2132
# jiancong 2133
# jiancong 2134
# jiancong 2135
# jiancong 2136
# jiancong 2137
# jiancong 2138
# jiancong 2139
# jiancong 2140
# jiancong 2141
# jiancong 2142
# jiancong 2143
# jiancong 2144
# jiancong 2145
# jiancong 2146
# jiancong 2147
# jiancong 2148
# jiancong 2149
# jiancong 2150
# jiancong 2151
# jiancong 2152
# jiancong 2153
# jiancong 2154
# jiancong 2155
# jiancong 2156
# jiancong 2157
# jiancong 2158
# jiancong 2159
# jiancong 2160
# jiancong 2161
# jiancong 2162
# jiancong 2163
# jiancong 2164
# jiancong 2165
# jiancong 2166
# jiancong 2167
# jiancong 2168
# jiancong 2169
# jiancong 2170
# jiancong 2171
# jiancong 2172
# jiancong 2173
# jiancong 2174
# jiancong 2175
# jiancong 2176
# jiancong 2177
# jiancong 2178
# jiancong 2179
# jiancong 2180
# jiancong 2181
# jiancong 2182
# jiancong 2183
# jiancong 2184
# jiancong 2185
# jiancong 2186
# jiancong 2187
# jiancong 2188
# jiancong 2189
# jiancong 2190
# jiancong 2191
# jiancong 2192
# jiancong 2193
# jiancong 2194
# jiancong 2195
# jiancong 2196
# jiancong 2197
# jiancong 2198
# jiancong 2199
# jiancong 2200
# jiancong 2201
# jiancong 2202
# jiancong 2203
# jiancong 2204
# jiancong 2205
# jiancong 2206
# jiancong 2207
# jiancong 2208
# jiancong 2209
# jiancong 2210
# jiancong 2211
# jiancong 2212
# jiancong 2213
# jiancong 2214
# jiancong 2215
# jiancong 2216
# jiancong 2217
# jiancong 2218
# jiancong 2219
# jiancong 2220
# jiancong 2221
# jiancong 2222
# jiancong 2223
# jiancong 2224
# jiancong 2225
# jiancong 2226
# jiancong 2227
# jiancong 2228
# jiancong 2229
# jiancong 2230
# jiancong 2231
# jiancong 2232
# jiancong 2233
# jiancong 2234
# jiancong 2235
# jiancong 2236
# jiancong 2237
# jiancong 2238
# jiancong 2239
# jiancong 2240
# jiancong 2241
# jiancong 2242
# jiancong 2243
# jiancong 2244
# jiancong 2245
# jiancong 2246
# jiancong 2247
# jiancong 2248
# jiancong 2249
# jiancong 2250
# jiancong 2251
# jiancong 2252
# jiancong 2253
# jiancong 2254
# jiancong 2255
# jiancong 2256
# jiancong 2257
# jiancong 2258
# jiancong 2259
# jiancong 2260
# jiancong 2261
# jiancong 2262
# jiancong 2263
# jiancong 2264
# jiancong 2265
# jiancong 2266
# jiancong 2267
# jiancong 2268
# jiancong 2269
# jiancong 2270
# jiancong 2271
# jiancong 2272
# jiancong 2273
# jiancong 2274
# jiancong 2275
# jiancong 2276
# jiancong 2277
# jiancong 2278
# jiancong 2279
# jiancong 2280
# jiancong 2281
# jiancong 2282
# jiancong 2283
# jiancong 2284
# jiancong 2285
# jiancong 2286
# jiancong 2287
# jiancong 2288
# jiancong 2289
# jiancong 2290
# jiancong 2291
# jiancong 2292
# jiancong 2293
# jiancong 2294
# jiancong 2295
# jiancong 2296
# jiancong 2297
# jiancong 2298
# jiancong 2299
# jiancong 2300
# jiancong 2301
# jiancong 2302
# jiancong 2303
# jiancong 2304
# jiancong 2305
# jiancong 2306
# jiancong 2307
# jiancong 2308
# jiancong 2309
# jiancong 2310
# jiancong 2311
# jiancong 2312
# jiancong 2313
# jiancong 2314
# jiancong 2315
# jiancong 2316
# jiancong 2317
# jiancong 2318
# jiancong 2319
# jiancong 2320
# jiancong 2321
# jiancong 2322
# jiancong 2323
# jiancong 2324
# jiancong 2325
# jiancong 2326
# jiancong 2327
# jiancong 2328
# jiancong 2329
# jiancong 2330
# jiancong 2331
# jiancong 2332
# jiancong 2333
# jiancong 2334
# jiancong 2335
# jiancong 2336
# jiancong 2337
# jiancong 2338
# jiancong 2339
# jiancong 2340
# jiancong 2341
# jiancong 2342
# jiancong 2343
# jiancong 2344
# jiancong 2345
# jiancong 2346
# jiancong 2347
# jiancong 2348
# jiancong 2349
# jiancong 2350
# jiancong 2351
# jiancong 2352
# jiancong 2353
# jiancong 2354
# jiancong 2355
# jiancong 2356
# jiancong 2357
# jiancong 2358
# jiancong 2359
# jiancong 2360
# jiancong 2361
# jiancong 2362
# jiancong 2363
# jiancong 2364
# jiancong 2365
# jiancong 2366
# jiancong 2367
# jiancong 2368
# jiancong 2369
# jiancong 2370
# jiancong 2371
# jiancong 2372
# jiancong 2373
# jiancong 2374
# jiancong 2375
# jiancong 2376
# jiancong 2377
# jiancong 2378
# jiancong 2379
# jiancong 2380
# jiancong 2381
# jiancong 2382
# jiancong 2383
# jiancong 2384
# jiancong 2385
# jiancong 2386
# jiancong 2387
# jiancong 2388
# jiancong 2389
# jiancong 2390
# jiancong 2391
# jiancong 2392
# jiancong 2393
# jiancong 2394
# jiancong 2395
# jiancong 2396
# jiancong 2397
# jiancong 2398
# jiancong 2399
# jiancong 2400
# jiancong 2401
# jiancong 2402
# jiancong 2403
# jiancong 2404
# jiancong 2405
# jiancong 2406
# jiancong 2407
# jiancong 2408
# jiancong 2409
# jiancong 2410
# jiancong 2411
# jiancong 2412
# jiancong 2413
# jiancong 2414
# jiancong 2415
# jiancong 2416
# jiancong 2417
# jiancong 2418
# jiancong 2419
# jiancong 2420
# jiancong 2421
# jiancong 2422
# jiancong 2423
# jiancong 2424
# jiancong 2425
# jiancong 2426
# jiancong 2427
# jiancong 2428
# jiancong 2429
# jiancong 2430
# jiancong 2431
# jiancong 2432
# jiancong 2433
# jiancong 2434
# jiancong 2435
# jiancong 2436
# jiancong 2437
# jiancong 2438
# jiancong 2439
# jiancong 2440
# jiancong 2441
# jiancong 2442
# jiancong 2443
# jiancong 2444
# jiancong 2445
# jiancong 2446
# jiancong 2447
# jiancong 2448
# jiancong 2449
# jiancong 2450
# jiancong 2451
# jiancong 2452
# jiancong 2453
# jiancong 2454
# jiancong 2455
# jiancong 2456
# jiancong 2457
# jiancong 2458
# jiancong 2459
# jiancong 2460
# jiancong 2461
# jiancong 2462
# jiancong 2463
# jiancong 2464
# jiancong 2465
# jiancong 2466
# jiancong 2467
# jiancong 2468
# jiancong 2469
# jiancong 2470
# jiancong 2471
# jiancong 2472
# jiancong 2473
# jiancong 2474
# jiancong 2475
# jiancong 2476
# jiancong 2477
# jiancong 2478
# jiancong 2479
# jiancong 2480
# jiancong 2481
# jiancong 2482
# jiancong 2483
# jiancong 2484
# jiancong 2485
# jiancong 2486
# jiancong 2487
# jiancong 2488
# jiancong 2489
# jiancong 2490
# jiancong 2491
# jiancong 2492
# jiancong 2493
# jiancong 2494
# jiancong 2495
# jiancong 2496
# jiancong 2497
# jiancong 2498
# jiancong 2499
# jiancong 2500
# jiancong 2501
# jiancong 2502
# jiancong 2503
# jiancong 2504
# jiancong 2505
# jiancong 2506
# jiancong 2507
# jiancong 2508
# jiancong 2509
# jiancong 2510
# jiancong 2511
# jiancong 2512
# jiancong 2513
# jiancong 2514
# jiancong 2515
# jiancong 2516
# jiancong 2517
# jiancong 2518
# jiancong 2519
# jiancong 2520
# jiancong 2521
# jiancong 2522
# jiancong 2523
# jiancong 2524
# jiancong 2525
# jiancong 2526
# jiancong 2527
# jiancong 2528
# jiancong 2529
# jiancong 2530
# jiancong 2531
# jiancong 2532
# jiancong 2533
# jiancong 2534
# jiancong 2535
# jiancong 2536
# jiancong 2537
# jiancong 2538
# jiancong 2539
# jiancong 2540
# jiancong 2541
# jiancong 2542
# jiancong 2543
# jiancong 2544
# jiancong 2545
# jiancong 2546
# jiancong 2547
# jiancong 2548
# jiancong 2549
# jiancong 2550
# jiancong 2551
# jiancong 2552
# jiancong 2553
# jiancong 2554
# jiancong 2555
# jiancong 2556
# jiancong 2557
# jiancong 2558
# jiancong 2559
# jiancong 2560
# jiancong 2561
# jiancong 2562
# jiancong 2563
# jiancong 2564
# jiancong 2565
# jiancong 2566
# jiancong 2567
# jiancong 2568
# jiancong 2569
# jiancong 2570
# jiancong 2571
# jiancong 2572
# jiancong 2573
# jiancong 2574
# jiancong 2575
# jiancong 2576
# jiancong 2577
# jiancong 2578
# jiancong 2579
# jiancong 2580
# jiancong 2581
# jiancong 2582
# jiancong 2583
# jiancong 2584
# jiancong 2585
# jiancong 2586
# jiancong 2587
# jiancong 2588
# jiancong 2589
# jiancong 2590
# jiancong 2591
# jiancong 2592
# jiancong 2593
# jiancong 2594
# jiancong 2595
# jiancong 2596
# jiancong 2597
# jiancong 2598
# jiancong 2599
# jiancong 2600
# jiancong 2601
# jiancong 2602
# jiancong 2603
# jiancong 2604
# jiancong 2605
# jiancong 2606
# jiancong 2607
# jiancong 2608
# jiancong 2609
# jiancong 2610
# jiancong 2611
# jiancong 2612
# jiancong 2613
# jiancong 2614
# jiancong 2615
# jiancong 2616
# jiancong 2617
# jiancong 2618
# jiancong 2619
# jiancong 2620
# jiancong 2621
# jiancong 2622
# jiancong 2623
# jiancong 2624
# jiancong 2625
# jiancong 2626
# jiancong 2627
# jiancong 2628
# jiancong 2629
# jiancong 2630
# jiancong 2631
# jiancong 2632
# jiancong 2633
# jiancong 2634
# jiancong 2635
# jiancong 2636
# jiancong 2637
# jiancong 2638
# jiancong 2639
# jiancong 2640
# jiancong 2641
# jiancong 2642
# jiancong 2643
# jiancong 2644
# jiancong 2645
# jiancong 2646
# jiancong 2647
# jiancong 2648
# jiancong 2649
# jiancong 2650
# jiancong 2651
# jiancong 2652
# jiancong 2653
# jiancong 2654
# jiancong 2655
# jiancong 2656
# jiancong 2657
# jiancong 2658
# jiancong 2659
# jiancong 2660
# jiancong 2661
# jiancong 2662
# jiancong 2663
# jiancong 2664
# jiancong 2665
# jiancong 2666
# jiancong 2667
# jiancong 2668
# jiancong 2669
# jiancong 2670
# jiancong 2671
# jiancong 2672
# jiancong 2673
# jiancong 2674
# jiancong 2675
# jiancong 2676
# jiancong 2677
# jiancong 2678
# jiancong 2679
# jiancong 2680
# jiancong 2681
# jiancong 2682
# jiancong 2683
# jiancong 2684
# jiancong 2685
# jiancong 2686
# jiancong 2687
# jiancong 2688
# jiancong 2689
# jiancong 2690
# jiancong 2691
# jiancong 2692
# jiancong 2693
# jiancong 2694
# jiancong 2695
# jiancong 2696
# jiancong 2697
# jiancong 2698
# jiancong 2699
# jiancong 2700
# jiancong 2701
# jiancong 2702
# jiancong 2703
# jiancong 2704
# jiancong 2705
# jiancong 2706
# jiancong 2707
# jiancong 2708
# jiancong 2709
# jiancong 2710
# jiancong 2711
# jiancong 2712
# jiancong 2713
# jiancong 2714
# jiancong 2715
# jiancong 2716
# jiancong 2717
# jiancong 2718
# jiancong 2719
# jiancong 2720
# jiancong 2721
# jiancong 2722
# jiancong 2723
# jiancong 2724
# jiancong 2725
# jiancong 2726
# jiancong 2727
# jiancong 2728
# jiancong 2729
# jiancong 2730
# jiancong 2731
# jiancong 2732
# jiancong 2733
# jiancong 2734
# jiancong 2735
# jiancong 2736
# jiancong 2737
# jiancong 2738
# jiancong 2739
# jiancong 2740
# jiancong 2741
# jiancong 2742
# jiancong 2743
# jiancong 2744
# jiancong 2745
# jiancong 2746
# jiancong 2747
# jiancong 2748
# jiancong 2749
# jiancong 2750
# jiancong 2751
# jiancong 2752
# jiancong 2753
# jiancong 2754
# jiancong 2755
# jiancong 2756
# jiancong 2757
# jiancong 2758
# jiancong 2759
# jiancong 2760
# jiancong 2761
# jiancong 2762
# jiancong 2763
# jiancong 2764
# jiancong 2765
# jiancong 2766
# jiancong 2767
# jiancong 2768
# jiancong 2769
# jiancong 2770
# jiancong 2771
# jiancong 2772
# jiancong 2773
# jiancong 2774
# jiancong 2775
# jiancong 2776
# jiancong 2777
# jiancong 2778
# jiancong 2779
# jiancong 2780
# jiancong 2781
# jiancong 2782
# jiancong 2783
# jiancong 2784
# jiancong 2785
# jiancong 2786
# jiancong 2787
# jiancong 2788
# jiancong 2789
# jiancong 2790
# jiancong 2791
# jiancong 2792
# jiancong 2793
# jiancong 2794
# jiancong 2795
# jiancong 2796
# jiancong 2797
# jiancong 2798
# jiancong 2799
# jiancong 2800
# jiancong 2801
# jiancong 2802
# jiancong 2803
# jiancong 2804
# jiancong 2805
# jiancong 2806
# jiancong 2807
# jiancong 2808
# jiancong 2809
# jiancong 2810
# jiancong 2811
# jiancong 2812
# jiancong 2813
# jiancong 2814
# jiancong 2815
# jiancong 2816
# jiancong 2817
# jiancong 2818
# jiancong 2819
# jiancong 2820
# jiancong 2821
# jiancong 2822
# jiancong 2823
# jiancong 2824
# jiancong 2825
# jiancong 2826
# jiancong 2827
# jiancong 2828
# jiancong 2829
# jiancong 2830
# jiancong 2831
# jiancong 2832
# jiancong 2833
# jiancong 2834
# jiancong 2835
# jiancong 2836
# jiancong 2837
# jiancong 2838
# jiancong 2839
# jiancong 2840
# jiancong 2841
# jiancong 2842
# jiancong 2843
# jiancong 2844
# jiancong 2845
# jiancong 2846
# jiancong 2847
# jiancong 2848
# jiancong 2849
# jiancong 2850
# jiancong 2851
# jiancong 2852
# jiancong 2853
# jiancong 2854
# jiancong 2855
# jiancong 2856
# jiancong 2857
# jiancong 2858
# jiancong 2859
# jiancong 2860
# jiancong 2861
# jiancong 2862
# jiancong 2863
# jiancong 2864
# jiancong 2865
# jiancong 2866
# jiancong 2867
# jiancong 2868
# jiancong 2869
# jiancong 2870
# jiancong 2871
# jiancong 2872
# jiancong 2873
# jiancong 2874
# jiancong 2875
# jiancong 2876
# jiancong 2877
# jiancong 2878
# jiancong 2879
# jiancong 2880
# jiancong 2881
# jiancong 2882
# jiancong 2883
# jiancong 2884
# jiancong 2885
# jiancong 2886
# jiancong 2887
# jiancong 2888
# jiancong 2889
# jiancong 2890
# jiancong 2891
# jiancong 2892
# jiancong 2893
# jiancong 2894
# jiancong 2895
# jiancong 2896
# jiancong 2897
# jiancong 2898
# jiancong 2899
# jiancong 2900
# jiancong 2901
# jiancong 2902
# jiancong 2903
# jiancong 2904
# jiancong 2905
# jiancong 2906
# jiancong 2907
# jiancong 2908
# jiancong 2909
# jiancong 2910
# jiancong 2911
# jiancong 2912
# jiancong 2913
# jiancong 2914
# jiancong 2915
# jiancong 2916
# jiancong 2917
# jiancong 2918
# jiancong 2919
# jiancong 2920
# jiancong 2921
# jiancong 2922
# jiancong 2923
# jiancong 2924
# jiancong 2925
# jiancong 2926
# jiancong 2927
# jiancong 2928
# jiancong 2929
# jiancong 2930
# jiancong 2931
# jiancong 2932
# jiancong 2933
# jiancong 2934
# jiancong 2935
# jiancong 2936
# jiancong 2937
# jiancong 2938
# jiancong 2939
# jiancong 2940
# jiancong 2941
# jiancong 2942
# jiancong 2943
# jiancong 2944
# jiancong 2945
# jiancong 2946
# jiancong 2947
# jiancong 2948
# jiancong 2949
# jiancong 2950
# jiancong 2951
# jiancong 2952
# jiancong 2953
# jiancong 2954
# jiancong 2955
# jiancong 2956
# jiancong 2957
# jiancong 2958
# jiancong 2959
# jiancong 2960
# jiancong 2961
# jiancong 2962
# jiancong 2963
# jiancong 2964
# jiancong 2965
# jiancong 2966
# jiancong 2967
# jiancong 2968
# jiancong 2969
# jiancong 2970
# jiancong 2971
# jiancong 2972
# jiancong 2973
# jiancong 2974
# jiancong 2975
# jiancong 2976
# jiancong 2977
# jiancong 2978
# jiancong 2979
# jiancong 2980
# jiancong 2981
# jiancong 2982
# jiancong 2983
# jiancong 2984
# jiancong 2985
# jiancong 2986
# jiancong 2987
# jiancong 2988
# jiancong 2989
# jiancong 2990
# jiancong 2991
# jiancong 2992
# jiancong 2993
# jiancong 2994
# jiancong 2995
# jiancong 2996
# jiancong 2997
# jiancong 2998
# jiancong 2999
# jiancong 3000
# jiancong 3001
# jiancong 3002
# jiancong 3003
# jiancong 3004
# jiancong 3005
# jiancong 3006
# jiancong 3007
# jiancong 3008
# jiancong 3009
# jiancong 3010
# jiancong 3011
# jiancong 3012
# jiancong 3013
# jiancong 3014
# jiancong 3015
# jiancong 3016
# jiancong 3017
# jiancong 3018
# jiancong 3019
# jiancong 3020
# jiancong 3021
# jiancong 3022
# jiancong 3023
# jiancong 3024
# jiancong 3025
# jiancong 3026
# jiancong 3027
# jiancong 3028
# jiancong 3029
# jiancong 3030
# jiancong 3031
# jiancong 3032
# jiancong 3033
# jiancong 3034
# jiancong 3035
# jiancong 3036
# jiancong 3037
# jiancong 3038
# jiancong 3039
# jiancong 3040
# jiancong 3041
# jiancong 3042
# jiancong 3043
# jiancong 3044
# jiancong 3045
# jiancong 3046
# jiancong 3047
# jiancong 3048
# jiancong 3049
# jiancong 3050
# jiancong 3051
# jiancong 3052
# jiancong 3053
# jiancong 3054
# jiancong 3055
# jiancong 3056
# jiancong 3057
# jiancong 3058
# jiancong 3059
# jiancong 3060
# jiancong 3061
# jiancong 3062
# jiancong 3063
# jiancong 3064
# jiancong 3065
# jiancong 3066
# jiancong 3067
# jiancong 3068
# jiancong 3069
# jiancong 3070
# jiancong 3071
# jiancong 3072
# jiancong 3073
# jiancong 3074
# jiancong 3075
# jiancong 3076
# jiancong 3077
# jiancong 3078
# jiancong 3079
# jiancong 3080
# jiancong 3081
# jiancong 3082
# jiancong 3083
# jiancong 3084
# jiancong 3085
# jiancong 3086
# jiancong 3087
# jiancong 3088
# jiancong 3089
# jiancong 3090
# jiancong 3091
# jiancong 3092
# jiancong 3093
# jiancong 3094
# jiancong 3095
# jiancong 3096
# jiancong 3097
# jiancong 3098
# jiancong 3099
# jiancong 3100
# jiancong 3101
# jiancong 3102
# jiancong 3103
# jiancong 3104
# jiancong 3105
# jiancong 3106
# jiancong 3107
# jiancong 3108
# jiancong 3109
# jiancong 3110
# jiancong 3111
# jiancong 3112
# jiancong 3113
# jiancong 3114
# jiancong 3115
# jiancong 3116
# jiancong 3117
# jiancong 3118
# jiancong 3119
# jiancong 3120
# jiancong 3121
# jiancong 3122
# jiancong 3123
# jiancong 3124
# jiancong 3125
# jiancong 3126
# jiancong 3127
# jiancong 3128
# jiancong 3129
# jiancong 3130
# jiancong 3131
# jiancong 3132
# jiancong 3133
# jiancong 3134
# jiancong 3135
# jiancong 3136
# jiancong 3137
# jiancong 3138
# jiancong 3139
# jiancong 3140
# jiancong 3141
# jiancong 3142
# jiancong 3143
# jiancong 3144
# jiancong 3145
# jiancong 3146
# jiancong 3147
# jiancong 3148
# jiancong 3149
# jiancong 3150
# jiancong 3151
# jiancong 3152
# jiancong 3153
# jiancong 3154
# jiancong 3155
# jiancong 3156
# jiancong 3157
# jiancong 3158
# jiancong 3159
# jiancong 3160
# jiancong 3161
# jiancong 3162
# jiancong 3163
# jiancong 3164
# jiancong 3165
# jiancong 3166
# jiancong 3167
# jiancong 3168
# jiancong 3169
# jiancong 3170
# jiancong 3171
# jiancong 3172
# jiancong 3173
# jiancong 3174
# jiancong 3175
# jiancong 3176
# jiancong 3177
# jiancong 3178
# jiancong 3179
# jiancong 3180
# jiancong 3181
# jiancong 3182
# jiancong 3183
# jiancong 3184
# jiancong 3185
# jiancong 3186
# jiancong 3187
# jiancong 3188
# jiancong 3189
# jiancong 3190
# jiancong 3191
# jiancong 3192
# jiancong 3193
# jiancong 3194
# jiancong 3195
# jiancong 3196
# jiancong 3197
# jiancong 3198
# jiancong 3199
# jiancong 3200
# jiancong 3201
# jiancong 3202
# jiancong 3203
# jiancong 3204
# jiancong 3205
# jiancong 3206
# jiancong 3207
# jiancong 3208
# jiancong 3209
# jiancong 3210
# jiancong 3211
# jiancong 3212
# jiancong 3213
# jiancong 3214
# jiancong 3215
# jiancong 3216
# jiancong 3217
# jiancong 3218
# jiancong 3219
# jiancong 3220
# jiancong 3221
# jiancong 3222
# jiancong 3223
# jiancong 3224
# jiancong 3225
# jiancong 3226
# jiancong 3227
# jiancong 3228
# jiancong 3229
# jiancong 3230
# jiancong 3231
# jiancong 3232
# jiancong 3233
# jiancong 3234
# jiancong 3235
# jiancong 3236
# jiancong 3237
# jiancong 3238
# jiancong 3239
# jiancong 3240
# jiancong 3241
# jiancong 3242
# jiancong 3243
# jiancong 3244
# jiancong 3245
# jiancong 3246
# jiancong 3247
# jiancong 3248
# jiancong 3249
# jiancong 3250
# jiancong 3251
# jiancong 3252
# jiancong 3253
# jiancong 3254
# jiancong 3255
# jiancong 3256
# jiancong 3257
# jiancong 3258
# jiancong 3259
# jiancong 3260
# jiancong 3261
# jiancong 3262
# jiancong 3263
# jiancong 3264
# jiancong 3265
# jiancong 3266
# jiancong 3267
# jiancong 3268
# jiancong 3269
# jiancong 3270
# jiancong 3271
# jiancong 3272
# jiancong 3273
# jiancong 3274
# jiancong 3275
# jiancong 3276
# jiancong 3277
# jiancong 3278
# jiancong 3279
# jiancong 3280
# jiancong 3281
# jiancong 3282
# jiancong 3283
# jiancong 3284
# jiancong 3285
# jiancong 3286
# jiancong 3287
# jiancong 3288
# jiancong 3289
# jiancong 3290
# jiancong 3291
# jiancong 3292
# jiancong 3293
# jiancong 3294
# jiancong 3295
# jiancong 3296
# jiancong 3297
# jiancong 3298
# jiancong 3299
# jiancong 3300
# jiancong 3301
# jiancong 3302
# jiancong 3303
# jiancong 3304
# jiancong 3305
# jiancong 3306
# jiancong 3307
# jiancong 3308
# jiancong 3309
# jiancong 3310
# jiancong 3311
# jiancong 3312
# jiancong 3313
# jiancong 3314
# jiancong 3315
# jiancong 3316
# jiancong 3317
# jiancong 3318
# jiancong 3319
# jiancong 3320
# jiancong 3321
# jiancong 3322
# jiancong 3323
# jiancong 3324
# jiancong 3325
# jiancong 3326
# jiancong 3327
# jiancong 3328
# jiancong 3329
# jiancong 3330
# jiancong 3331
# jiancong 3332
# jiancong 3333
# jiancong 3334
# jiancong 3335
# jiancong 3336
# jiancong 3337
# jiancong 3338
# jiancong 3339
# jiancong 3340
# jiancong 3341
# jiancong 3342
# jiancong 3343
# jiancong 3344
# jiancong 3345
# jiancong 3346
# jiancong 3347
# jiancong 3348
# jiancong 3349
# jiancong 3350
# jiancong 3351
# jiancong 3352
# jiancong 3353
# jiancong 3354
# jiancong 3355
# jiancong 3356
# jiancong 3357
# jiancong 3358
# jiancong 3359
# jiancong 3360
# jiancong 3361
# jiancong 3362
# jiancong 3363
# jiancong 3364
# jiancong 3365
# jiancong 3366
# jiancong 3367
# jiancong 3368
# jiancong 3369
# jiancong 3370
# jiancong 3371
# jiancong 3372
# jiancong 3373
# jiancong 3374
# jiancong 3375
# jiancong 3376
# jiancong 3377
# jiancong 3378
# jiancong 3379
# jiancong 3380
# jiancong 3381
# jiancong 3382
# jiancong 3383
# jiancong 3384
# jiancong 3385
# jiancong 3386
# jiancong 3387
# jiancong 3388
# jiancong 3389
# jiancong 3390
# jiancong 3391
# jiancong 3392
# jiancong 3393
# jiancong 3394
# jiancong 3395
# jiancong 3396
# jiancong 3397
# jiancong 3398
# jiancong 3399
# jiancong 3400
# jiancong 3401
# jiancong 3402
# jiancong 3403
# jiancong 3404
# jiancong 3405
# jiancong 3406
# jiancong 3407
# jiancong 3408
# jiancong 3409
# jiancong 3410
# jiancong 3411
# jiancong 3412
# jiancong 3413
# jiancong 3414
# jiancong 3415
# jiancong 3416
# jiancong 3417
# jiancong 3418
# jiancong 3419
# jiancong 3420
# jiancong 3421
# jiancong 3422
# jiancong 3423
# jiancong 3424
# jiancong 3425
# jiancong 3426
# jiancong 3427
# jiancong 3428
# jiancong 3429
# jiancong 3430
# jiancong 3431
# jiancong 3432
# jiancong 3433
# jiancong 3434
# jiancong 3435
# jiancong 3436
# jiancong 3437
# jiancong 3438
# jiancong 3439
# jiancong 3440
# jiancong 3441
# jiancong 3442
# jiancong 3443
# jiancong 3444
# jiancong 3445
# jiancong 3446
# jiancong 3447
# jiancong 3448
# jiancong 3449
# jiancong 3450
# jiancong 3451
# jiancong 3452
# jiancong 3453
# jiancong 3454
# jiancong 3455
# jiancong 3456
# jiancong 3457
# jiancong 3458
# jiancong 3459
# jiancong 3460
# jiancong 3461
# jiancong 3462
# jiancong 3463
# jiancong 3464
# jiancong 3465
# jiancong 3466
# jiancong 3467
# jiancong 3468
# jiancong 3469
# jiancong 3470
# jiancong 3471
# jiancong 3472
# jiancong 3473
# jiancong 3474
# jiancong 3475
# jiancong 3476
# jiancong 3477
# jiancong 3478
# jiancong 3479
# jiancong 3480
# jiancong 3481
# jiancong 3482
# jiancong 3483
# jiancong 3484
# jiancong 3485
# jiancong 3486
# jiancong 3487
# jiancong 3488
# jiancong 3489
# jiancong 3490
# jiancong 3491
# jiancong 3492
# jiancong 3493
# jiancong 3494
# jiancong 3495
# jiancong 3496
# jiancong 3497
# jiancong 3498
# jiancong 3499
# jiancong 3500
# jiancong 3501
# jiancong 3502
# jiancong 3503
# jiancong 3504
# jiancong 3505
# jiancong 3506
# ...
# jiancong 4380
# jiancong 4381
# jiancong 4382
# jiancong 4383
# jiancong 4384
# jiancong 4385
# jiancong 4386
# jiancong 4387
# jiancong 4388
# jiancong 4389
# jiancong 4390
# jiancong 4391
# jiancong 4392
# jiancong 4393
# jiancong 4394
# jiancong 4395
# jiancong 4396
# jiancong 4397
# jiancong 4398
# jiancong 4399
# jiancong 4400
# jiancong 4401
# jiancong 4402
# jiancong 4403
# jiancong 4404
# jiancong 4405
# jiancong 4406
# jiancong 4407
# jiancong 4408
# jiancong 4409
# jiancong 4410
# jiancong 4411
# jiancong 4412
# jiancong 4413
# jiancong 4414
# jiancong 4415
# jiancong 4416
# jiancong 4417
# jiancong 4418
# jiancong 4419
# jiancong 4420
# jiancong 4421
# jiancong 4422
# jiancong 4423
# jiancong 4424
# jiancong 4425
# jiancong 4426
# jiancong 4427
# jiancong 4428
# jiancong 4429
# jiancong 4430
# jiancong 4431
# jiancong 4432
# jiancong 4433
# jiancong 4434
# jiancong 4435
# jiancong 4436
# jiancong 4437
# jiancong 4438
# jiancong 4439
# jiancong 4440
# jiancong 4441
# jiancong 4442
# jiancong 4443
# jiancong 4444
# jiancong 4445
# jiancong 4446
# jiancong 4447
# jiancong 4448
# jiancong 4449
# jiancong 4450
# jiancong 4451
# jiancong 4452
# jiancong 4453
# jiancong 4454
# jiancong 4455
# jiancong 4456
# jiancong 4457
# jiancong 4458
# jiancong 4459
# jiancong 4460
# jiancong 4461
# jiancong 4462
# jiancong 4463
# jiancong 4464
# jiancong 4465
# jiancong 4466
# jiancong 4467
# jiancong 4468
# jiancong 4469
# jiancong 4470
# jiancong 4471
# jiancong 4472
# jiancong 4473
# jiancong 4474
# jiancong 4475
# jiancong 4476
# jiancong 4477
# jiancong 4478
# jiancong 4479
# jiancong 4480
# jiancong 4481
# jiancong 4482
# jiancong 4483
# jiancong 4484
# jiancong 4485
# jiancong 4486
# jiancong 4487
# jiancong 4488
# jiancong 4489
# jiancong 4490
# jiancong 4491
# jiancong 4492
# jiancong 4493
# jiancong 4494
# jiancong 4495
# jiancong 4496
# jiancong 4497
# jiancong 4498
# jiancong 4499
# jiancong 4500
# jiancong 4501
# jiancong 4502
# jiancong 4503
# jiancong 4504
# jiancong 4505
# jiancong 4506
# jiancong 4507
# jiancong 4508
# jiancong 4509
# jiancong 4510
# jiancong 4511
# jiancong 4512
# jiancong 4513
# jiancong 4514
# jiancong 4515
# jiancong 4516
# jiancong 4517
# jiancong 4518
# jiancong 4519
# jiancong 4520
# jiancong 4521
# jiancong 4522
# jiancong 4523
# jiancong 4524
# jiancong 4525
# jiancong 4526
# jiancong 4527
# jiancong 4528
# jiancong 4529
# jiancong 4530
# jiancong 4531
# jiancong 4532
# jiancong 4533
# jiancong 4534
# jiancong 4535
# jiancong 4536
# jiancong 4537
# jiancong 4538
# jiancong 4539
# jiancong 4540
# jiancong 4541
# jiancong 4542
# jiancong 4543
# jiancong 4544
# jiancong 4545
# jiancong 4546
# jiancong 4547
# jiancong 4548
# jiancong 4549
# jiancong 4550
# jiancong 4551
# jiancong 4552
# jiancong 4553
# jiancong 4554
# jiancong 4555
# jiancong 4556
# jiancong 4557
# jiancong 4558
# jiancong 4559
# jiancong 4560
# jiancong 4561
# jiancong 4562
# jiancong 4563
# jiancong 4564
# jiancong 4565
# jiancong 4566
# jiancong 4567
# jiancong 4568
# jiancong 4569
# jiancong 4570
# jiancong 4571
# jiancong 4572
# jiancong 4573
# jiancong 4574
# jiancong 4575
# jiancong 4576
# jiancong 4577
# jiancong 4578
# jiancong 4579
# jiancong 4580
# jiancong 4581
# jiancong 4582
# jiancong 4583
# jiancong 4584
# jiancong 4585
# jiancong 4586
# jiancong 4587
# jiancong 4588
# jiancong 4589
# jiancong 4590
# jiancong 4591
# jiancong 4592
# jiancong 4593
# jiancong 4594
# jiancong 4595
# jiancong 4596
# jiancong 4597
# jiancong 4598
# jiancong 4599
# jiancong 4600
# jiancong 4601
# jiancong 4602
# jiancong 4603
# jiancong 4604
# jiancong 4605
# jiancong 4606
# jiancong 4607
# jiancong 4608
# jiancong 4609
# jiancong 4610
# jiancong 4611
# jiancong 4612
# jiancong 4613
# jiancong 4614
# jiancong 4615
# jiancong 4616
# jiancong 4617
# jiancong 4618
# jiancong 4619
# jiancong 4620
# jiancong 4621
# jiancong 4622
# jiancong 4623
# jiancong 4624
# jiancong 4625
# jiancong 4626
# jiancong 4627
# jiancong 4628
# jiancong 4629
# jiancong 4630
# jiancong 4631
# jiancong 4632
# jiancong 4633
# jiancong 4634
# jiancong 4635
# jiancong 4636
# jiancong 4637
# jiancong 4638
# jiancong 4639
# jiancong 4640
# jiancong 4641
# jiancong 4642
# jiancong 4643
# jiancong 4644
# jiancong 4645
# jiancong 4646
# jiancong 4647
# jiancong 4648
# jiancong 4649
# jiancong 4650
# jiancong 4651
# jiancong 4652
# jiancong 4653
# jiancong 4654
# jiancong 4655
# jiancong 4656
# jiancong 4657
# jiancong 4658
# jiancong 4659
# jiancong 4660
# jiancong 4661
# jiancong 4662
# jiancong 4663
# jiancong 4664
# jiancong 4665
# jiancong 4666
# jiancong 4667
# jiancong 4668
# jiancong 4669
# jiancong 4670
# jiancong 4671
# jiancong 4672
# jiancong 4673
# jiancong 4674
# jiancong 4675
# jiancong 4676
# jiancong 4677
# jiancong 4678
# jiancong 4679
# jiancong 4680
# jiancong 4681
# jiancong 4682
# jiancong 4683
# jiancong 4684
# jiancong 4685
# jiancong 4686
# jiancong 4687
# jiancong 4688
# jiancong 4689
# jiancong 4690
# jiancong 4691
# jiancong 4692
# jiancong 4693
# jiancong 4694
# jiancong 4695
# jiancong 4696
# jiancong 4697
# jiancong 4698
# jiancong 4699
# jiancong 4700
# jiancong 4701
# jiancong 4702
# jiancong 4703
# jiancong 4704
# jiancong 4705
# jiancong 4706
# jiancong 4707
# jiancong 4708
# jiancong 4709
# jiancong 4710
# jiancong 4711
# jiancong 4712
# jiancong 4713
# jiancong 4714
# jiancong 4715
# jiancong 4716
# jiancong 4717
# jiancong 4718
# jiancong 4719
# jiancong 4720
# jiancong 4721
# jiancong 4722
# jiancong 4723
# jiancong 4724
# jiancong 4725
# jiancong 4726
# jiancong 4727
# jiancong 4728
# jiancong 4729
# jiancong 4730
# jiancong 4731
# jiancong 4732
# jiancong 4733
# jiancong 4734
# jiancong 4735
# jiancong 4736
# jiancong 4737
# jiancong 4738
# jiancong 4739
# jiancong 4740
# jiancong 4741
# jiancong 4742
# jiancong 4743
# jiancong 4744
# jiancong 4745
# jiancong 4746
# jiancong 4747
# jiancong 4748
# jiancong 4749
# jiancong 4750
# jiancong 4751
# jiancong 4752
# jiancong 4753
# jiancong 4754
# jiancong 4755
# jiancong 4756
# jiancong 4757
# jiancong 4758
# jiancong 4759
# jiancong 4760
# jiancong 4761
# jiancong 4762
# jiancong 4763
# jiancong 4764
# jiancong 4765
# jiancong 4766
# jiancong 4767
# jiancong 4768
# jiancong 4769
# jiancong 4770
# jiancong 4771
# jiancong 4772
# jiancong 4773
# jiancong 4774
# jiancong 4775
# jiancong 4776
# jiancong 4777
# jiancong 4778
# jiancong 4779
# jiancong 4780
# jiancong 4781
# jiancong 4782
# jiancong 4783
# jiancong 4784
# jiancong 4785
# jiancong 4786
# jiancong 4787
# jiancong 4788
# jiancong 4789
# jiancong 4790
# jiancong 4791
# jiancong 4792
# jiancong 4793
# jiancong 4794
# jiancong 4795
# jiancong 4796
# jiancong 4797
# jiancong 4798
# jiancong 4799
# jiancong 4800
# jiancong 4801
# jiancong 4802
# jiancong 4803
# jiancong 4804
# jiancong 4805
# jiancong 4806
# jiancong 4807
# jiancong 4808
# jiancong 4809
# jiancong 4810
# jiancong 4811
# jiancong 4812
# jiancong 4813
# jiancong 4814
# jiancong 4815
# jiancong 4816
# jiancong 4817
# jiancong 4818
# jiancong 4819
# jiancong 4820
# jiancong 4821
# jiancong 4822
# jiancong 4823
# jiancong 4824
# jiancong 4825
# jiancong 4826
# jiancong 4827
# jiancong 4828
# jiancong 4829
# jiancong 4830
# jiancong 4831
# jiancong 4832
# jiancong 4833
# jiancong 4834
# jiancong 4835
# jiancong 4836
# jiancong 4837
# jiancong 4838
# jiancong 4839
# jiancong 4840
# jiancong 4841
# jiancong 4842
# jiancong 4843
# jiancong 4844
# jiancong 4845
# jiancong 4846
# jiancong 4847
# jiancong 4848
# jiancong 4849
# jiancong 4850
# jiancong 4851
# jiancong 4852
# jiancong 4853
# jiancong 4854
# jiancong 4855
# jiancong 4856
# jiancong 4857
# jiancong 4858
# jiancong 4859
# jiancong 4860
# jiancong 4861
# jiancong 4862
# jiancong 4863
# jiancong 4864
# jiancong 4865
# jiancong 4866
# jiancong 4867
# jiancong 4868
# jiancong 4869
# jiancong 4870
# jiancong 4871
# jiancong 4872
# jiancong 4873
# jiancong 4874
# jiancong 4875
# jiancong 4876
# jiancong 4877
# jiancong 4878
# jiancong 4879
# jiancong 4880
# jiancong 4881
# jiancong 4882
# jiancong 4883
# jiancong 4884
# jiancong 4885
# jiancong 4886
# jiancong 4887
# jiancong 4888
# jiancong 4889
# jiancong 4890
# jiancong 4891
# jiancong 4892
# jiancong 4893
# jiancong 4894
# jiancong 4895
# jiancong 4896
# jiancong 4897
# jiancong 4898
# jiancong 4899
# jiancong 4900
# jiancong 4901
# jiancong 4902
# jiancong 4903
# jiancong 4904
# jiancong 4905
# jiancong 4906
# jiancong 4907
# jiancong 4908
# jiancong 4909
# jiancong 4910
# jiancong 4911
# jiancong 4912
# jiancong 4913
# jiancong 4914
# jiancong 4915
# jiancong 4916
# jiancong 4917
# jiancong 4918
# jiancong 4919
# jiancong 4920
# jiancong 4921
# jiancong 4922
# jiancong 4923
# jiancong 4924
# jiancong 4925
# jiancong 4926
# jiancong 4927
# jiancong 4928
# jiancong 4929
# jiancong 4930
# jiancong 4931
# jiancong 4932
# jiancong 4933
# jiancong 4934
# jiancong 4935
# jiancong 4936
# jiancong 4937
# jiancong 4938
# jiancong 4939
# jiancong 4940
# jiancong 4941
# jiancong 4942
# jiancong 4943
# jiancong 4944
# jiancong 4945
# jiancong 4946
# jiancong 4947
# jiancong 4948
# jiancong 4949
# jiancong 4950
# jiancong 4951
# jiancong 4952
# jiancong 4953
# jiancong 4954
# jiancong 4955
# jiancong 4956
# jiancong 4957
# jiancong 4958
# jiancong 4959
# jiancong 4960
# jiancong 4961
# jiancong 4962
# jiancong 4963
# jiancong 4964
# jiancong 4965
# jiancong 4966
# jiancong 4967
# jiancong 4968
# jiancong 4969
# jiancong 4970
# jiancong 4971
# jiancong 4972
# jiancong 4973
# jiancong 4974
# jiancong 4975
# jiancong 4976
# jiancong 4977
# jiancong 4978
# jiancong 4979
# jiancong 4980
# jiancong 4981
# jiancong 4982
# jiancong 4983
# jiancong 4984
# jiancong 4985
# jiancong 4986
# jiancong 4987
# jiancong 4988
# jiancong 4989
# jiancong 4990
# jiancong 4991
# jiancong 4992
# jiancong 4993
# jiancong 4994
# jiancong 4995
# jiancong 4996
# jiancong 4997
# jiancong 4998
# jiancong 4999
# jiancong 5000
# jiancong 5001
# jiancong 5002
# jiancong 5003
# jiancong 5004
# jiancong 5005
# jiancong 5006
# jiancong 5007
# jiancong 5008
# jiancong 5009
# jiancong 5010
# jiancong 5011
# jiancong 5012
# jiancong 5013
# jiancong 5014
# jiancong 5015
# jiancong 5016
# jiancong 5017
# jiancong 5018
# jiancong 5019
# jiancong 5020
# jiancong 5021
# jiancong 5022
# jiancong 5023
# jiancong 5024
# jiancong 5025
# jiancong 5026
# jiancong 5027
# jiancong 5028
# jiancong 5029
# jiancong 5030
# jiancong 5031
# jiancong 5032
# jiancong 5033
# jiancong 5034
# jiancong 5035
# jiancong 5036
# jiancong 5037
# jiancong 5038
# jiancong 5039
# jiancong 5040
# jiancong 5041
# jiancong 5042
# jiancong 5043
# jiancong 5044
# jiancong 5045
# jiancong 5046
# jiancong 5047
# jiancong 5048
# jiancong 5049
# jiancong 5050
# jiancong 5051
# jiancong 5052
# jiancong 5053
# jiancong 5054
# jiancong 5055
# jiancong 5056
# jiancong 5057
# jiancong 5058
# jiancong 5059
# jiancong 5060
# jiancong 5061
# jiancong 5062
# jiancong 5063
# jiancong 5064
# jiancong 5065
# jiancong 5066
# jiancong 5067
# jiancong 5068
# jiancong 5069
# jiancong 5070
# jiancong 5071
# jiancong 5072
# jiancong 5073
# jiancong 5074
# jiancong 5075
# jiancong 5076
# jiancong 5077
# jiancong 5078
# jiancong 5079
# jiancong 5080
# jiancong 5081
# jiancong 5082
# jiancong 5083
# jiancong 5084
# jiancong 5085
# jiancong 5086
# jiancong 5087
# jiancong 5088
# jiancong 5089
# jiancong 5090
# jiancong 5091
# jiancong 5092
# jiancong 5093
# jiancong 5094
# jiancong 5095
# jiancong 5096
# jiancong 5097
# jiancong 5098
# jiancong 5099
# jiancong 5100
# jiancong 5101
# jiancong 5102
# jiancong 5103
# jiancong 5104
# jiancong 5105
# jiancong 5106
# jiancong 5107
# jiancong 5108
# jiancong 5109
# jiancong 5110
# jiancong 5111
# jiancong 5112
# jiancong 5113
# jiancong 5114
# jiancong 5115
# jiancong 5116
# jiancong 5117
# jiancong 5118
# jiancong 5119
# jiancong 5120
# jiancong 5121
# jiancong 5122
# jiancong 5123
# jiancong 5124
# jiancong 5125
# jiancong 5126
# jiancong 5127
# jiancong 5128
# jiancong 5129
# jiancong 5130
# jiancong 5131
# jiancong 5132
# jiancong 5133
# jiancong 5134
# jiancong 5135
# jiancong 5136
# jiancong 5137
# jiancong 5138
# jiancong 5139
# jiancong 5140
# jiancong 5141
# jiancong 5142
# jiancong 5143
# jiancong 5144
# jiancong 5145
# jiancong 5146
# jiancong 5147
# jiancong 5148
# jiancong 5149
# jiancong 5150
# jiancong 5151
# jiancong 5152
# jiancong 5153
# jiancong 5154
# jiancong 5155
# jiancong 5156
# jiancong 5157
# jiancong 5158
# jiancong 5159
# jiancong 5160
# jiancong 5161
# jiancong 5162
# jiancong 5163
# jiancong 5164
# jiancong 5165
# jiancong 5166
# jiancong 5167
# jiancong 5168
# jiancong 5169
# jiancong 5170
# jiancong 5171
# jiancong 5172
# jiancong 5173
# jiancong 5174
# jiancong 5175
# jiancong 5176
# jiancong 5177
# jiancong 5178
# jiancong 5179
# jiancong 5180
# jiancong 5181
# jiancong 5182
# jiancong 5183
# jiancong 5184
# jiancong 5185
# jiancong 5186
# jiancong 5187
# jiancong 5188
# jiancong 5189
# jiancong 5190
# jiancong 5191
# jiancong 5192
# jiancong 5193
# jiancong 5194
# jiancong 5195
# jiancong 5196
# jiancong 5197
# jiancong 5198
# jiancong 5199
# jiancong 5200
# jiancong 5201
# jiancong 5202
# jiancong 5203
# jiancong 5204
# jiancong 5205
# jiancong 5206
# jiancong 5207
# jiancong 5208
# jiancong 5209
# jiancong 5210
# jiancong 5211
# jiancong 5212
# jiancong 5213
# jiancong 5214
# jiancong 5215
# jiancong 5216
# jiancong 5217
# jiancong 5218
# jiancong 5219
# jiancong 5220
# jiancong 5221
# jiancong 5222
# jiancong 5223
# jiancong 5224
# jiancong 5225
# jiancong 5226
# jiancong 5227
# jiancong 5228
# jiancong 5229
# jiancong 5230
# jiancong 5231
# jiancong 5232
# jiancong 5233
# jiancong 5234
# jiancong 5235
# jiancong 5236
# jiancong 5237
# jiancong 5238
# jiancong 5239
# jiancong 5240
# jiancong 5241
# jiancong 5242
# jiancong 5243
# jiancong 5244
# jiancong 5245
# jiancong 5246
# jiancong 5247
# jiancong 5248
# jiancong 5249
# jiancong 5250
# jiancong 5251
# jiancong 5252
# jiancong 5253
# jiancong 5254
# jiancong 5255
# jiancong 5256
# jiancong 5257
# jiancong 5258
# jiancong 5259
# jiancong 5260
# jiancong 5261
# jiancong 5262
# jiancong 5263
# jiancong 5264
# jiancong 5265
# jiancong 5266
# jiancong 5267
# jiancong 5268
# jiancong 5269
# jiancong 5270
# jiancong 5271
# jiancong 5272
# jiancong 5273
# jiancong 5274
# jiancong 5275
# jiancong 5276
# jiancong 5277
# jiancong 5278
# jiancong 5279
# jiancong 5280
# jiancong 5281
# jiancong 5282
# jiancong 5283
# jiancong 5284
# jiancong 5285
# jiancong 5286
# jiancong 5287
# jiancong 5288
# jiancong 5289
# jiancong 5290
# jiancong 5291
# jiancong 5292
# jiancong 5293
# jiancong 5294
# jiancong 5295
# jiancong 5296
# jiancong 5297
# jiancong 5298
# jiancong 5299
# jiancong 5300
# jiancong 5301
# jiancong 5302
# jiancong 5303
# jiancong 5304
# jiancong 5305
# jiancong 5306
# jiancong 5307
# jiancong 5308
# jiancong 5309
# jiancong 5310
# jiancong 5311
# jiancong 5312
# jiancong 5313
# jiancong 5314
# jiancong 5315
# jiancong 5316
# jiancong 5317
# jiancong 5318
# jiancong 5319
# jiancong 5320
# jiancong 5321
# jiancong 5322
# jiancong 5323
# jiancong 5324
# jiancong 5325
# jiancong 5326
# jiancong 5327
# jiancong 5328
# jiancong 5329
# jiancong 5330
# jiancong 5331
# jiancong 5332
# jiancong 5333
# jiancong 5334
# jiancong 5335
# jiancong 5336
# jiancong 5337
# jiancong 5338
# jiancong 5339
# jiancong 5340
# jiancong 5341
# jiancong 5342
# jiancong 5343
# jiancong 5344
# jiancong 5345
# jiancong 5346
# jiancong 5347
# jiancong 5348
# jiancong 5349
# jiancong 5350
# jiancong 5351
# jiancong 5352
# jiancong 5353
# jiancong 5354
# jiancong 5355
# jiancong 5356
# jiancong 5357
# jiancong 5358
# jiancong 5359
# jiancong 5360
# jiancong 5361
# jiancong 5362
# jiancong 5363
# jiancong 5364
# jiancong 5365
# jiancong 5366
# jiancong 5367
# jiancong 5368
# jiancong 5369
# jiancong 5370
# jiancong 5371
# jiancong 5372
# jiancong 5373
# jiancong 5374
# jiancong 5375
# jiancong 5376
# jiancong 5377
# jiancong 5378
# jiancong 5379
# jiancong 5380
# jiancong 5381
# jiancong 5382
# jiancong 5383
# jiancong 5384
# jiancong 5385
# jiancong 5386
# jiancong 5387
# jiancong 5388
# jiancong 5389
# jiancong 5390
# jiancong 5391
# jiancong 5392
# jiancong 5393
# jiancong 5394
# jiancong 5395
# jiancong 5396
# jiancong 5397
# jiancong 5398
# jiancong 5399
# jiancong 5400
# jiancong 5401
# jiancong 5402
# jiancong 5403
# jiancong 5404
# jiancong 5405
# jiancong 5406
# jiancong 5407
# jiancong 5408
# jiancong 5409
# jiancong 5410
# jiancong 5411
# jiancong 5412
# jiancong 5413
# jiancong 5414
# jiancong 5415
# jiancong 5416
# jiancong 5417
# jiancong 5418
# jiancong 5419
# jiancong 5420
# jiancong 5421
# jiancong 5422
# jiancong 5423
# jiancong 5424
# jiancong 5425
# jiancong 5426
# jiancong 5427
# jiancong 5428
# jiancong 5429
# jiancong 5430
# jiancong 5431
# jiancong 5432
# jiancong 5433
# jiancong 5434
# jiancong 5435
# jiancong 5436
# jiancong 5437
# jiancong 5438
# jiancong 5439
# jiancong 5440
# jiancong 5441
# jiancong 5442
# jiancong 5443
# jiancong 5444
# jiancong 5445
# jiancong 5446
# jiancong 5447
# jiancong 5448
# jiancong 5449
# jiancong 5450
# jiancong 5451
# jiancong 5452
# jiancong 5453
# jiancong 5454
# jiancong 5455
# jiancong 5456
# jiancong 5457
# jiancong 5458
# jiancong 5459
# jiancong 5460
# jiancong 5461
# jiancong 5462
# jiancong 5463
# jiancong 5464
# jiancong 5465
# jiancong 5466
# jiancong 5467
# jiancong 5468
# jiancong 5469
# jiancong 5470
# jiancong 5471
# jiancong 5472
# jiancong 5473
# jiancong 5474
# jiancong 5475
# jiancong 5476
# jiancong 5477
# jiancong 5478
# jiancong 5479
# jiancong 5480
# jiancong 5481
# jiancong 5482
# jiancong 5483
# jiancong 5484
# jiancong 5485
# jiancong 5486
# jiancong 5487
# jiancong 5488
# jiancong 5489
# jiancong 5490
# jiancong 5491
# jiancong 5492
# jiancong 5493
# jiancong 5494
# jiancong 5495
# jiancong 5496
# jiancong 5497
# jiancong 5498
# jiancong 5499
# jiancong 5500
# jiancong 5501
# jiancong 5502
# jiancong 5503
# jiancong 5504
# jiancong 5505
# jiancong 5506
# jiancong 5507
# jiancong 5508
# jiancong 5509
# jiancong 5510
# jiancong 5511
# jiancong 5512
# jiancong 5513
# jiancong 5514
# jiancong 5515
# Target temp 29.0 not achievable, selecting next best value.
# Processing time: 105.60 minutes

# %%
#asssuming there's multiple key for target temp
unique_keys = [key for key in stored_dictionary.keys() if key.startswith("Dictionary for target temp") or key.startswith("Best alternative for target temp")]
print(unique_keys)

current_temperature = 28
target_temp = 25
key_to_find = f"Dictionary for target temp: {target_temp}"




def expandPath(row_index):
    for i in range(1, aircon_units + 1):
        print("UNIT " + str(i) + ":", end=' ')
        print(aircon_status_result[f"FC_Unit_{i}_Status"].iloc[row_index], end=' ')
        print(aircon_status_result[f"FC_Unit_{i}_Fan_Status"].iloc[row_index], end=' ')
        print(aircon_status_result[f"FC_Unit_{i}_Set_Point"].iloc[row_index], end=' ')
        print(aircon_status_result[f"FC_Unit_{i}_Operation_Mode"].iloc[row_index], end=' ')
        print("")
        
def findClosestTemperature(current_temp, paths):
    """Find the index of the closest available temperature in the paths dictionary."""
    closest_temp_index = None
    smallest_difference = float('inf')
    
    for key, value in paths.items():
        if value['starting_temp'] and value['path']:  #ensure that paths[index] has both values in 'starting_temp' and 'path'
            difference = abs(value['starting_temp'] - current_temp)
            if difference < smallest_difference:
                smallest_difference = difference
                closest_temp_index = key   
    return closest_temp_index


# Check if either key exists in stored_dictionary
if key_to_find in stored_dictionary:
    stored_dict_key = stored_dictionary[key_to_find]


    filtered_paths = {
        key: value for key, value in stored_dict_key.items()
        if (abs(value['starting_temp'] - current_temperature) < acceptable_range)
    }
    
    if filtered_paths:
        # Find the path with the smallest factor
        smallest_factor_path = min(filtered_paths.keys(), key=lambda x: filtered_paths[x]['factor'])
        print(stored_dict_key[smallest_factor_path])
    
        for index, value in enumerate(stored_dict_key[smallest_factor_path]['path']):
            expandPath(value)
            print("For", end=" ")
            hours, remainder = divmod(stored_dict_key[smallest_factor_path]['time_taken'][index], 3600)
            minutes, seconds = divmod(remainder, 60)
            print(f"Hours: {hours}, Minutes: {minutes}, Seconds: {seconds}")
            print("")
    else:
        print("No paths found within the acceptable range.")
        print("Finding the closest temperature in the algorithm.")
    
        closest_temp_index = findClosestTemperature(current_temperature, paths)
        
        if closest_temp_index is not None:
            
            print("Closest temperature found at index:", closest_temp_index , "\n")
            print(paths[closest_temp_index])
            
            for index, value in enumerate(stored_dict_key[closest_temp_index]['path']):
                expandPath(value)
                print("For", end=" ")
                hours, remainder = divmod(stored_dict_key[closest_temp_index]['time_taken'][index], 3600)
                minutes, seconds = divmod(remainder, 60)
                print(f"Hours: {hours}, Minutes: {minutes}, Seconds: {seconds}")
                print("")
        else:
            print("No valid paths available, even for the closest temperature.")

else:
    print(f"{key_to_find} does not exist")
# Out:
# ['Dictionary for target temp: 20.0', 'Dictionary for target temp: 20.5', 'Dictionary for target temp: 21.0', 'Dictionary for target temp: 21.5', 'Dictionary for target temp: 22.0', 'Dictionary for target temp: 22.5', 'Dictionary for target temp: 23.0', 'Dictionary for target temp: 23.5', 'Dictionary for target temp: 24.0', 'Dictionary for target temp: 24.5', 'Dictionary for target temp: 25.0', 'Dictionary for target temp: 25.5', 'Dictionary for target temp: 26.0', 'Dictionary for target temp: 26.5', 'Dictionary for target temp: 27.0', 'Dictionary for target temp: 27.5', 'Dictionary for target temp: 28.0', 'Dictionary for target temp: 28.5', 'Dictionary for target temp: 29.0']
# Dictionary for target temp: 25 does not exist

# %%
unique_keys = [key for key in stored_dictionary.keys() if key.startswith("Dictionary for target temp") or key.startswith("Best alternative for target temp")]
print(unique_keys)
# Out:
# ['Dictionary for target temp: 20.0', 'Dictionary for target temp: 20.5', 'Dictionary for target temp: 21.0', 'Dictionary for target temp: 21.5', 'Dictionary for target temp: 22.0', 'Dictionary for target temp: 22.5', 'Dictionary for target temp: 23.0', 'Dictionary for target temp: 23.5', 'Dictionary for target temp: 24.0', 'Dictionary for target temp: 24.5', 'Dictionary for target temp: 25.0', 'Dictionary for target temp: 25.5', 'Dictionary for target temp: 26.0', 'Dictionary for target temp: 26.5', 'Dictionary for target temp: 27.0', 'Dictionary for target temp: 27.5', 'Dictionary for target temp: 28.0', 'Dictionary for target temp: 28.5', 'Dictionary for target temp: 29.0']
