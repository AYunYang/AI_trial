# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import joblib
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#Reading Data from CSV Files
temperature_readings = pd.read_csv('data/data.csv') #original dataset for temp readings 
temperature_readings = temperature_readings.interpolate(method='linear')#fill in null values


weather_readings = pd.read_csv('data/weatherData.csv') #orignal dataset for weather readings

# Converting date and time in temperature_readings to UNIX timestamp for comparision 
temperature_readings['datetime_str'] = temperature_readings['date'] + ' ' + temperature_readings['time']
temperature_readings['datetime'] = temperature_readings['datetime_str'].apply(lambda x: datetime.strptime(x, "%a %b %d %Y %I:%M:%S %p"))
temperature_readings['unix_timestamp'] = temperature_readings['datetime'].apply(lambda x: int(x.timestamp()))

# Converting date and time in weather_readings to UNIX timestamp for comparision 
weather_readings['datetime_str'] = weather_readings['date'] + ' ' + weather_readings['time']
weather_readings['datetime'] = weather_readings['datetime_str'].apply(lambda x: datetime.strptime(x, "%a %b %d %Y %I:%M:%S %p"))
weather_readings['unix_timestamp'] = weather_readings['datetime'].apply(lambda x: int(x.timestamp()))

weather_result_col = [col for col in weather_readings.columns if "result" in col.lower()]

# Merging both data for it to be on the same time
merged_data = pd.merge_asof(
    temperature_readings,  # Left DataFrame
    weather_readings[['unix_timestamp']+weather_result_col],      # Right DataFrame
    on='unix_timestamp',   # Key column
    direction='nearest'    # Match the nearest time
)

datetime_string = merged_data['date'] + " " + merged_data["time"]
merged_data["ISO_formatted_datetime"] = pd.to_datetime(
    datetime_string,
    format="%a %b %d %Y %I:%M:%S %p"
)
print(merged_data["ISO_formatted_datetime"])

# #Columns for lorWan Sensors
temperature_col = [
    col for col in merged_data.columns 
    if "lorawan_readings" in col.lower() and "temperature" in col.lower()
]

humidity_col = [
    col for col in merged_data.columns 
    if "humidity" in col.lower() and "lorawan_readings" in col.lower()
]

co2_col = [
    col for col in merged_data.columns 
    if "co2" in col.lower() and "lorawan_readings" in col.lower()
]

sensors_to_keep = ["Sensor_1", "Sensor_3", "Sensor_6"]
sensors_col = [col for col in merged_data.columns if any(sensor in col for sensor in sensors_to_keep)]

weather_cols_to_keep = ["weather_status","weather_temp","weather_humidity"]
weather_col = [col for col in merged_data.columns if any(weathercol in col for weathercol in weather_cols_to_keep)]

#Energy(power,energy,current) Data
energy_data = merged_data[["date", "time"]+ sensors_col]
print(energy_data.info())

#indoor Data
indoor_data = merged_data[["date", "time"] + temperature_col + humidity_col + co2_col]
print(indoor_data.info())

#Weather data
weather_data = merged_data[["date", "time"]+ weather_col]
print(weather_data.info())
# Out:
# 0     2024-11-15 16:25:07
# 1     2024-11-15 16:30:06
# 2     2024-11-15 16:35:06
# 3     2024-11-15 16:40:05
# 4     2024-11-15 16:45:06
#               ...
# 598   2024-11-21 15:49:03
# 599   2024-11-21 15:53:50
# 600   2024-11-21 16:00:02
# 601   2024-11-21 16:05:38
# 602   2024-11-21 16:11:04
# Name: ISO_formatted_datetime, Length: 603, dtype: datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date                              603 non-null    object
#  1   time                              603 non-null    object
#  2   Energy_Readings.Sensor_1.Current  603 non-null    float64
#  3   Energy_Readings.Sensor_1.Energy   603 non-null    float64
#  4   Energy_Readings.Sensor_1.Power    603 non-null    float64
#  5   Energy_Readings.Sensor_3.Current  603 non-null    float64
#  6   Energy_Readings.Sensor_3.Energy   603 non-null    float64
#  7   Energy_Readings.Sensor_3.Power    603 non-null    float64
#  8   Energy_Readings.Sensor_6.Current  603 non-null    float64
#  9   Energy_Readings.Sensor_6.Energy   603 non-null    float64
#  10  Energy_Readings.Sensor_6.Power    603 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 51.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 22 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   date                                           603 non-null    object
#  1   time                                           603 non-null    object
#  2   Lorawan_Readings.24E124725E332564.temperature  603 non-null    float64
#  3   Lorawan_Readings.24E124725E331695.temperature  603 non-null    float64
#  4   Lorawan_Readings.24E124136D316361.temperature  603 non-null    float64
#  5   Lorawan_Readings.24E124725E331744.temperature  603 non-null    float64
#  6   Lorawan_Readings.24E124725E332483.temperature  603 non-null    float64
#  7   Lorawan_Readings.24E124725E331733.temperature  603 non-null    float64
#  8   Lorawan_Readings.24E124725E290348.temperature  603 non-null    float64
#  9   Lorawan_Readings.24E124725E286745.temperature  603 non-null    float64
#  10  Lorawan_Readings.24E124725E285123.temperature  603 non-null    float64
#  11  Lorawan_Readings.24E124725E332564.humidity     603 non-null    float64
#  12  Lorawan_Readings.24E124725E331695.humidity     603 non-null    float64
#  13  Lorawan_Readings.24E124136D316361.humidity     603 non-null    float64
#  14  Lorawan_Readings.24E124725E331744.humidity     603 non-null    float64
#  15  Lorawan_Readings.24E124725E332483.humidity     603 non-null    float64
#  16  Lorawan_Readings.24E124725E331733.humidity     603 non-null    float64
#  17  Lorawan_Readings.24E124725E290348.humidity     603 non-null    float64
#  18  Lorawan_Readings.24E124725E286745.humidity     603 non-null    float64
#  19  Lorawan_Readings.24E124725E285123.humidity     603 non-null    float64
#  20  Lorawan_Readings.24E124725E286745.co2          603 non-null    float64
#  21  Lorawan_Readings.24E124725E285123.co2          603 non-null    float64
# dtypes: float64(20), object(2)
# memory usage: 103.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     603 non-null    object
#  1   time                     603 non-null    object
#  2   result.weather_status    603 non-null    object
#  3   result.weather_temp      603 non-null    float64
#  4   result.weather_humidity  603 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 23.7+ KB
# None
# C:\Users\yy\AppData\Local\Temp\ipykernel_22148\670999370.py:18: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   temperature_readings = temperature_readings.interpolate(method='linear')#fill in null values
