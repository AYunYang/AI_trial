# %%
import json
import pandas as pd
import numpy as np

Sensor_readings = pd.read_json('data/W512_readings.json')
Aircon_Data = pd.read_json('data/W512_aircon_status.json')
Weather_readings = pd.read_json('data/Weather_data.json')

def convert_AirconData(data):
    records = []
    
    for index, row in data.iterrows():
        # Parse FC_FullStatus_Readings if it's a string representation of a dictionary
        if isinstance(row['FC_FullStatus_Readings'], str):
            fc_readings = ast.literal_eval(row['FC_FullStatus_Readings'])
        else:
            fc_readings = row['FC_FullStatus_Readings']


        try:
            combined_datetime = pd.to_datetime(f"{row['date']} {row['time']}")
            formatted_datetime = pd.to_datetime(combined_datetime.strftime("%Y-%m-%d %H:%M:%S"))

        except Exception as e:
            print(f"Error combining datetime for row {index}: {e}")
            combined_datetime = None
            formatted_datetime = None

        
        # Create a record with base information
        record = {
            'Datetime': formatted_datetime
        }
        
        # Add each FC Unit's details as separate columns
        for unit, unit_data in fc_readings.items():
            record[f'{unit}_Status'] = unit_data['Status']
            record[f'{unit}_Fan_Status'] = unit_data['Fan_Status']
            record[f'{unit}_Set_Point'] = unit_data['Set_Point']
            record[f'{unit}_Operation_Mode'] = unit_data['Operation_Mode']
        
        records.append(record)
    
    # Create DataFrame
    df = pd.DataFrame(records)
    return df


def convert_sensorReadings(data):
    records = []
    
    # List of keys to exclude from Lorawan_Readings
    include_keys_1 = ["24E124725E285123", "24E124725E331695","24E124725E331744",
                      "24E124725E332483","24E124725E290348","24E124725E331733","24E124725E286745"]#"24E124136D316361" is suppiosed to be outdoor but it is not outdoor yet
    include_keys_2 = ["Sensor_1","Sensor_3","Sensor_6"]
    
    for index, row in data.iterrows():
        # Parse Energy_Readings if it's a string representation of a dictionary
        if isinstance(row['Energy_Readings'], str):
            Energy_readings = ast.literal_eval(row['Energy_Readings'])
        else:
            Energy_readings = row['Energy_Readings']
            
        # Parse Lorawan_Readings if it's a string representation of a dictionary
        if isinstance(row['Lorawan_Readings'], str):
            Lorawan_Readings = ast.literal_eval(row['Lorawan_Readings'])
        else:
            Lorawan_Readings = row['Lorawan_Readings']

        try:
            # Combine the date and time columns to create a datetime object
            combined_datetime = pd.to_datetime(f"{row['date']} {row['time']}")
            formatted_datetime = pd.to_datetime(combined_datetime.strftime("%Y-%m-%d %H:%M:%S"))
        except Exception as e:
            print(f"Error combining datetime for row {index}: {e}")
            formatted_datetime = None

        # Create a record with base information
        record = {
            'Datetime': formatted_datetime
        }
        
        # Add each Energy sensor's details as separate columns
        for unit, unit_data in Energy_readings.items():
            if unit not in include_keys_2:
                continue
                
            record[f'{unit}_Current'] = unit_data['Current']
            record[f'{unit}_Energy'] = unit_data['Energy']
            record[f'{unit}_Power'] = unit_data['Power']
        
        # Add each Lorawan device's details as separate columns
        for unit, unit_data in Lorawan_Readings.items():
            if unit not in include_keys_1:
                continue
            record[f'{unit}_Humidity'] = unit_data.get('humidity', None)
            record[f'{unit}_Temperature'] = unit_data.get('temperature', None)

            co2_value = unit_data.get('co2', None)
            if co2_value is not None:
                record[f'{unit}_CO2'] = co2_value

        # Append the record to the list of records
        records.append(record)
    df=pd.DataFrame(records)
    return df


def convert_weatherData(data):
    records = []
    for index, row in data.iterrows():
        # Parse Energy_Readings if it's a string representation of a dictionary
        if isinstance(row['result'], str):
            weather_results = ast.literal_eval(row['result'])
        else:
            weather_results = row['result']
            
        try:
            combined_datetime = pd.to_datetime(f"{row['date']} {row['time']}")
            formatted_datetime = pd.to_datetime(combined_datetime.strftime("%Y-%m-%d %H:%M:%S"))
        except Exception as e:
            print(f"Error combining datetime for row {index}: {e}")
            formatted_datetime = None

        record = {
            'Datetime': formatted_datetime
        }  

        record['weather_status'] = weather_results['weather_status']
        record['weather_temp'] = weather_results['weather_temp']
        record['weather_humid'] = weather_results['weather_humidity']
            
        records.append(record)
    df=pd.DataFrame(records)
    return df



Aircon_data_df = convert_AirconData(Aircon_Data)
Aircon_data_df = Aircon_data_df[3194:]
Sensor_readings_df = convert_sensorReadings(Sensor_readings)
Sensor_readings_df = Sensor_readings_df.interpolate(method='linear')
weather_readings_df = convert_weatherData(Weather_readings)

# Merge Aircon data with Sensor readings using merge_asof
merged_df = pd.merge_asof(Aircon_data_df, Sensor_readings_df, on='Datetime', direction='nearest')

# Now, merge the Weather readings with the previous result using merge_asof
merged_df = pd.merge_asof(merged_df, weather_readings_df, on='Datetime', direction='nearest')


merged_df['total_energy'] = (
    merged_df['Sensor_1_Energy'] +
    merged_df['Sensor_3_Energy'] +
    merged_df['Sensor_6_Energy']
)

merged_df['total_power'] = (
    merged_df['Sensor_1_Power'] +
    merged_df['Sensor_3_Power'] +
    merged_df['Sensor_6_Power']
)

merged_df['total_current'] = (
    merged_df['Sensor_1_Current'] +
    merged_df['Sensor_3_Current'] +
    merged_df['Sensor_6_Current']
)

temperature_col = [
    col for col in merged_df.columns 
    if "24e124" in col.lower() and "temperature" in col.lower()
]
humidity_col = [
    col for col in merged_df.columns 
    if "24e124" in col.lower() and "humidity" in col.lower()
]
co2_col = [
    col for col in merged_df.columns 
    if "24e124" in col.lower() and "co2" in col.lower()
]

merged_df['avg_temperature'] = merged_df[temperature_col].mean(axis=1)
merged_df['avg_humidity'] = merged_df[humidity_col].mean(axis=1)
merged_df['avg_co2'] = merged_df[co2_col].mean(axis=1)

# merged_df['future_timestamp'] = merged_df['Datetime'] + pd.Timedelta(minutes=30)

# merged_df['target_temperature'] = pd.merge_asof(
#     merged_df[['future_timestamp']].rename(columns={'future_timestamp': 'Datetime'}),
#     merged_df[['Datetime', 'avg_temperature']],
#     on='Datetime',
#     direction='nearest'
# )['avg_temperature']

# merged_df['target_humidity'] = pd.merge_asof(
#     merged_df[['future_timestamp']].rename(columns={'future_timestamp': 'Datetime'}),
#     merged_df[['Datetime', 'avg_humidity']],
#     on='Datetime',
#     direction='nearest'
# )['avg_humidity']

# merged_df['future_energy'] = pd.merge_asof(
#     merged_df[['future_timestamp']].rename(columns={'future_timestamp': 'Datetime'}),
#     merged_df[['Datetime', 'total_energy']],
#     on='Datetime',
#     direction='nearest'
# )['total_energy']

# merged_df['energy_difference'] = merged_df['future_energy'] - merged_df['total_energy']


dropped_col = [
    col for col in merged_df.columns
    if "24e124" in col.lower()
]
dropped_col_sensor = [
    col for col in merged_df.columns
    if "sensor" in col.lower()
]

columns_to_drop = dropped_col + dropped_col_sensor
merged_df.drop(columns=columns_to_drop, axis=1, inplace=True)

merged_df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       3 import numpy as np
# ----> 5 Sensor_readings = pd.read_json('data/W512_readings.json')
#       6 Aircon_Data = pd.read_json('data/W512_aircon_status.json')
#       7 Weather_readings = pd.read_json('data/Weather_data.json')
#
# File ~\anaconda3\envs\yy_1\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\anaconda3\envs\yy_1\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
#    1028         infer_objects=False, dtype_backend=self.dtype_backend
#    1029     )
#
# File ~\anaconda3\envs\yy_1\Lib\site-packages\pandas\io\json\_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File ~\anaconda3\envs\yy_1\Lib\site-packages\pandas\io\json\_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File ~\anaconda3\envs\yy_1\Lib\site-packages\pandas\io\json\_json.py:1403, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# ValueError: Expected object or value

# %%
import torch

# Convert DataFrame columns to PyTorch tensors
device = 'cuda' if torch.cuda.is_available() else 'cpu'

energy = torch.tensor(merged_df['total_energy'].values, device=device, dtype=torch.float32)
temperature = torch.tensor(merged_df['avg_temperature'].values, device=device, dtype=torch.float32)

# Convert Datetime column to seconds and move to GPU
datetime_seconds = torch.tensor(
    (merged_df['Datetime'] - merged_df['Datetime'].min()).dt.total_seconds().values,
    device=device,
    dtype=torch.float32
)

# Precompute min and max for normalization
min_energy = energy.min()
max_energy = energy.max()
min_temp = temperature.min()
max_temp = temperature.max()
min_time = datetime_seconds.min()
max_time = datetime_seconds.max()

# Weights for the cost function
energy_weight = 0.3
temp_weight = 0.3
time_weight = 0.4

#this is where you edit your variables
current_temperature = 25.0
target_temperature = 22.0
best_path = []
min_cost = float('inf')

# Memoization dictionary
memo = {}


def calculate_differences_gpu(row1_energy, row1_temp, row1_time, row2_energy, row2_temp, row2_time):
    # Calculate energy and temperature differences
    energy_diff = (torch.abs(row1_energy - row2_energy) - min_energy) / (max_energy - min_energy)
    temp_diff = (torch.abs((row1_temp + row2_temp) / 2 - target_temperature) - min_temp) / (max_temp - min_temp)
    # Calculate normalized time difference
    time_diff = (torch.abs(row1_time - row2_time) - min_time) / (max_time - min_time)
    return energy_diff, temp_diff, time_diff


def find_best_pathway(current_row_index, current_temp, path, total_cost, time_taken):
    global min_cost, best_path

    # Memoization key
    key = (current_row_index, tuple(path))
    if key in memo:
        return memo[key]

    # Base case: Target temperature reached
    if abs(current_temp - target_temperature) < 0.3:
        if total_cost < min_cost:
            min_cost = total_cost
            best_path = path[:]
        return total_cost, path[:], time_taken

    best_cost = float('inf')
    best_path_local = None

    for next_row_index in range(current_row_index + 1, len(energy)):
        # Calculate differences using tensors
        energy_diff, temp_diff, time_diff = calculate_differences_gpu(
            energy[current_row_index],
            temperature[current_row_index],
            datetime_seconds[current_row_index],
            energy[next_row_index],
            temperature[next_row_index],
            datetime_seconds[next_row_index]
        )

        # Compute cost
        cost = energy_diff * energy_weight + temp_diff * temp_weight + time_diff * time_weight

        # Pruning condition
        if total_cost + cost >= min_cost:
            continue

        # Recursive call
        new_cost, new_path, new_time_taken = find_best_pathway(
            next_row_index,
            temperature[next_row_index].item(),
            path + [next_row_index],
            total_cost + cost,
            time_taken + (datetime_seconds[next_row_index] - datetime_seconds[current_row_index]).item()
        )

        # Update best cost and path
        if new_cost < best_cost:
            best_cost = new_cost
            best_path_local = new_path

    # Store result in memo
    memo[key] = (best_cost, best_path_local, time_taken)
    return memo[key]


# Start the backtracking process
for start_index in range(len(energy)):
    if abs(temperature[start_index].item() - current_temperature) <= 0.5:
        print(f"Starting backtracking from index {start_index} with temperature {temperature[start_index].item()}")
        find_best_pathway(start_index, temperature[start_index].item(), [start_index], 0, 0)

# Output the result


fcunit_col = [
    col for col in merged_df.columns 
    if "fc_unit" in col.lower()
]
if best_path:
    print("Best Path:", best_path)
    print("Minimum Cost:", min_cost)
    
    # Convert time taken to minutes
    time_taken_in_minutes = sum([datetime_seconds[best_path[i]] - datetime_seconds[best_path[i-1]] for i in range(1, len(best_path))]).item() / 60
    print(f"Time Taken (in minutes): {time_taken_in_minutes:.2f}min to go from {current_temperature} to {target_temperature}")

    best_path_rows = merged_df.iloc[best_path][fcunit_col+['avg_temperature']]
    
    best_path_rows.to_csv(f'{current_temperature}_to_{target_temperature}.csv')
else:
    print("No valid pathway found.")
# Out:
# Starting from index 1022 with temperature 27.542856216430664
# Starting from index 1023 with temperature 27.549999237060547
# Starting from index 1024 with temperature 27.58571434020996
# Starting from index 1025 with temperature 27.600000381469727
# Starting from index 1026 with temperature 27.614286422729492
# Starting from index 1027 with temperature 27.64642906188965
# Starting from index 1028 with temperature 27.678571701049805
# Starting from index 1029 with temperature 27.696428298950195
# Starting from index 1030 with temperature 27.72857093811035
# Starting from index 1031 with temperature 27.75
# Starting from index 1032 with temperature 27.799999237060547
# Starting from index 1033 with temperature 27.821428298950195
# Starting from index 1034 with temperature 27.828571319580078
# Starting from index 1035 with temperature 27.85714340209961
# Starting from index 1036 with temperature 27.871429443359375
# Starting from index 1037 with temperature 27.899999618530273
# Starting from index 1038 with temperature 27.899999618530273
# Starting from index 1039 with temperature 27.933332443237305
# Starting from index 1040 with temperature 27.952381134033203
# Starting from index 1041 with temperature 27.985713958740234
# Starting from index 1042 with temperature 28.0
# Starting from index 1043 with temperature 28.014286041259766
# Starting from index 1044 with temperature 28.035715103149414
# Starting from index 1045 with temperature 28.05714225769043
# Starting from index 1046 with temperature 28.071428298950195
# Starting from index 1047 with temperature 28.100000381469727
# Starting from index 1048 with temperature 28.100000381469727
# Starting from index 1049 with temperature 28.128570556640625
# Starting from index 1050 with temperature 28.157142639160156
# Starting from index 1051 with temperature 28.200000762939453
# Starting from index 1052 with temperature 28.200000762939453
# Starting from index 1053 with temperature 28.22142791748047
# Starting from index 1054 with temperature 28.257143020629883
# Starting from index 1055 with temperature 28.27142906188965
# Starting from index 1056 with temperature 28.285715103149414
# Starting from index 1057 with temperature 28.30714225769043
# Starting from index 1058 with temperature 28.342857360839844
# Starting from index 1059 with temperature 28.35714340209961
# Starting from index 1060 with temperature 28.371429443359375
# Starting from index 1061 with temperature 28.371429443359375
# Starting from index 1062 with temperature 28.407142639160156
# Starting from index 1063 with temperature 28.44285774230957
# Starting from index 1064 with temperature 28.457143783569336
# Starting from index 1065 with temperature 28.457143783569336
# Starting from index 1066 with temperature 28.457143783569336
# Starting from index 1067 with temperature 28.5
# Starting from index 1143 with temperature 28.5
# Starting from index 1145 with temperature 28.485713958740234
# Starting from index 1146 with temperature 28.47857093811035
# Starting from index 1147 with temperature 28.47142791748047
# Starting from index 1148 with temperature 28.47142791748047
# Starting from index 1149 with temperature 28.47142791748047
# Starting from index 1150 with temperature 28.457143783569336
# Starting from index 1151 with temperature 28.44285774230957
# Starting from index 1152 with temperature 28.457143783569336
# Starting from index 1153 with temperature 28.44285774230957
# Starting from index 1154 with temperature 28.44285774230957
# Starting from index 1155 with temperature 28.428571701049805
# Starting from index 1156 with temperature 28.428571701049805
# Starting from index 1157 with temperature 28.399999618530273
# Starting from index 1158 with temperature 28.385713577270508
# Starting from index 1159 with temperature 28.378570556640625
# Starting from index 1160 with temperature 28.371429443359375
# Starting from index 1161 with temperature 28.371429443359375
# Starting from index 1162 with temperature 28.371429443359375
# Starting from index 1163 with temperature 28.35714340209961
# Starting from index 1164 with temperature 28.342857360839844
# Starting from index 1165 with temperature 28.342857360839844
# Starting from index 1166 with temperature 28.342857360839844
# Starting from index 1167 with temperature 28.328571319580078
# Starting from index 1168 with temperature 28.30714225769043
# Starting from index 1169 with temperature 28.285715103149414
# Starting from index 1170 with temperature 28.285715103149414
# Starting from index 1171 with temperature 28.285715103149414
# Starting from index 1172 with temperature 28.27142906188965
# Starting from index 1173 with temperature 28.27142906188965
# Starting from index 1174 with temperature 28.27142906188965
# Starting from index 1175 with temperature 28.257143020629883
# Starting from index 1176 with temperature 28.257143020629883
# Starting from index 1177 with temperature 28.242856979370117
# Starting from index 1178 with temperature 28.242856979370117
# Starting from index 1179 with temperature 28.214284896850586
# Starting from index 1180 with temperature 28.207143783569336
# Starting from index 1181 with temperature 28.214284896850586
# Starting from index 1182 with temperature 28.185714721679688
# Starting from index 1183 with temperature 28.185714721679688
# Starting from index 1184 with temperature 28.185714721679688
# Starting from index 1185 with temperature 28.157142639160156
# Starting from index 1186 with temperature 28.171428680419922
# Starting from index 1187 with temperature 28.14285659790039
# Starting from index 1188 with temperature 28.14285659790039
# Starting from index 1189 with temperature 28.128570556640625
# Starting from index 1190 with temperature 28.114286422729492
# Starting from index 1191 with temperature 28.092857360839844
# Starting from index 1192 with temperature 28.100000381469727
# Starting from index 1193 with temperature 28.08571434020996
# Starting from index 1194 with temperature 28.08571434020996
# Starting from index 1195 with temperature 28.071428298950195
# Starting from index 1196 with temperature 28.042856216430664
# Starting from index 1197 with temperature 28.042856216430664
# Starting from index 1198 with temperature 28.042856216430664
# Starting from index 1199 with temperature 28.042856216430664
# Starting from index 1200 with temperature 28.02857208251953
# Starting from index 1201 with temperature 28.02857208251953
# Starting from index 1202 with temperature 28.02857208251953
# Starting from index 1203 with temperature 28.02857208251953
# Starting from index 1204 with temperature 28.007143020629883
# Starting from index 1205 with temperature 28.0
# Starting from index 1206 with temperature 28.0
# Starting from index 1207 with temperature 27.985713958740234
# Starting from index 1208 with temperature 27.985713958740234
# Starting from index 1209 with temperature 27.97142791748047
# Starting from index 1210 with temperature 27.957143783569336
# Starting from index 1211 with temperature 28.0
# Starting from index 1212 with temperature 27.957143783569336
# Starting from index 1213 with temperature 27.94285774230957
# Starting from index 1214 with temperature 27.928571701049805
# Starting from index 1215 with temperature 27.94285774230957
# Starting from index 1216 with temperature 27.928571701049805
# Starting from index 1217 with temperature 27.94285774230957
# Starting from index 1218 with temperature 27.928571701049805
# Starting from index 1219 with temperature 27.928571701049805
# Starting from index 1220 with temperature 27.91428565979004
# Starting from index 1221 with temperature 27.899999618530273
# Starting from index 1222 with temperature 27.907142639160156
# Starting from index 1223 with temperature 27.885713577270508
# Starting from index 1224 with temperature 27.885713577270508
# Starting from index 1225 with temperature 27.871429443359375
# Starting from index 1226 with temperature 27.842857360839844
# Starting from index 1227 with temperature 27.85714340209961
# Starting from index 1228 with temperature 27.842857360839844
# Starting from index 1229 with temperature 27.842857360839844
# Starting from index 1230 with temperature 27.828571319580078
# Starting from index 1231 with temperature 27.828571319580078
# Starting from index 1232 with temperature 27.842857360839844
# Starting from index 1233 with temperature 27.814285278320312
# Starting from index 1234 with temperature 27.799999237060547
# Starting from index 1235 with temperature 27.814285278320312
# Starting from index 1236 with temperature 27.814285278320312
# Starting from index 1237 with temperature 27.80714225769043
# Starting from index 1238 with temperature 27.785715103149414
# Starting from index 1239 with temperature 27.757143020629883
# Starting from index 1240 with temperature 27.785715103149414
# Starting from index 1241 with temperature 27.77142906188965
# Starting from index 1242 with temperature 27.77142906188965
# Starting from index 1243 with temperature 27.77142906188965
# Starting from index 1244 with temperature 27.77142906188965
# Starting from index 1245 with temperature 27.77142906188965
# Starting from index 1246 with temperature 27.757143020629883
# Starting from index 1247 with temperature 27.757143020629883
# Starting from index 1248 with temperature 27.757143020629883
# Starting from index 1249 with temperature 27.757143020629883
# Starting from index 1250 with temperature 27.757143020629883
# Starting from index 1251 with temperature 27.77142906188965
# Starting from index 1252 with temperature 27.757143020629883
# Starting from index 1253 with temperature 27.77142906188965
# Starting from index 1254 with temperature 27.77142906188965
# Starting from index 1255 with temperature 27.77142906188965
# Starting from index 1256 with temperature 27.785715103149414
# Starting from index 1257 with temperature 27.785715103149414
# Starting from index 1258 with temperature 27.80476188659668
# Starting from index 1259 with temperature 27.809524536132812
# Starting from index 1260 with temperature 27.828571319580078
# Starting from index 1261 with temperature 27.828571319580078
# Starting from index 1262 with temperature 27.842857360839844
# Starting from index 1263 with temperature 27.871429443359375
# Starting from index 1264 with temperature 27.885713577270508
# Starting from index 1265 with temperature 27.89285659790039
# Starting from index 1266 with temperature 27.885713577270508
# Starting from index 1267 with temperature 27.91428565979004
# Starting from index 1268 with temperature 27.94285774230957
# Starting from index 1269 with temperature 27.985713958740234
# Starting from index 1270 with temperature 27.97142791748047
# Starting from index 1271 with temperature 28.0
# Starting from index 1272 with temperature 28.02857208251953
# Starting from index 1273 with temperature 28.02857208251953
# Starting from index 1274 with temperature 28.071428298950195
# Starting from index 1275 with temperature 28.08571434020996
# Starting from index 1276 with temperature 28.092857360839844
# Starting from index 1277 with temperature 28.114286422729492
# Starting from index 1278 with temperature 28.128570556640625
# Starting from index 1279 with temperature 28.171428680419922
# Starting from index 1280 with temperature 28.185714721679688
# Starting from index 1281 with temperature 28.200000762939453
# Starting from index 1282 with temperature 28.22857093811035
# Starting from index 1283 with temperature 28.242856979370117
# Starting from index 1284 with temperature 28.285715103149414
# Starting from index 1285 with temperature 28.292856216430664
# Starting from index 1286 with temperature 28.314285278320312
# Starting from index 1287 with temperature 28.328571319580078
# Starting from index 1288 with temperature 28.35714340209961
# Starting from index 1289 with temperature 28.385713577270508
# Starting from index 1290 with temperature 28.39285659790039
# Starting from index 1291 with temperature 28.428571701049805
# Starting from index 1292 with temperature 28.44285774230957
# Starting from index 1293 with temperature 28.457143783569336
# Starting from index 1294 with temperature 28.492856979370117
# Starting from index 1295 with temperature 28.5
# Starting from index 1374 with temperature 28.485713958740234
# Starting from index 1375 with temperature 28.47142791748047
# Starting from index 1376 with temperature 28.428571701049805
# Starting from index 1377 with temperature 28.428571701049805
# Starting from index 1378 with temperature 28.428571701049805
# Starting from index 1379 with temperature 28.41428565979004
# Starting from index 1380 with temperature 28.41428565979004
# Starting from index 1381 with temperature 28.41428565979004
# Starting from index 1382 with temperature 28.41428565979004
# Starting from index 1383 with temperature 28.41428565979004
# Starting from index 1384 with temperature 28.385713577270508
# Starting from index 1385 with temperature 28.371429443359375
# Starting from index 1386 with temperature 28.385713577270508
# Starting from index 1387 with temperature 28.371429443359375
# Starting from index 1388 with temperature 28.35714340209961
# Starting from index 1389 with temperature 28.342857360839844
# Starting from index 1390 with temperature 28.342857360839844
# Starting from index 1391 with temperature 28.328571319580078
# Starting from index 1392 with temperature 28.328571319580078
# Starting from index 1393 with temperature 28.328571319580078
# Starting from index 1394 with temperature 28.314285278320312
# Starting from index 1395 with temperature 28.314285278320312
# Starting from index 1396 with temperature 28.328571319580078
# Starting from index 1397 with temperature 28.314285278320312
# Starting from index 1398 with temperature 28.285715103149414
# Starting from index 1399 with temperature 28.299999237060547
# Starting from index 1400 with temperature 28.285715103149414
# Starting from index 1401 with temperature 28.285715103149414
# Starting from index 1402 with temperature 28.27142906188965
# Starting from index 1403 with temperature 28.242856979370117
# Starting from index 1404 with temperature 28.257143020629883
# Starting from index 1405 with temperature 28.257143020629883
# Starting from index 1406 with temperature 28.22857093811035
# Starting from index 1407 with temperature 28.242856979370117
# Starting from index 1408 with temperature 28.257143020629883
# Starting from index 1409 with temperature 28.242856979370117
# Starting from index 1410 with temperature 28.22857093811035
# Starting from index 1411 with temperature 28.22857093811035
# Starting from index 1412 with temperature 28.22857093811035
# Starting from index 1413 with temperature 28.22857093811035
# Starting from index 1414 with temperature 28.214284896850586
# Starting from index 1415 with temperature 28.214284896850586
# Starting from index 1416 with temperature 28.214284896850586
# Starting from index 1417 with temperature 28.200000762939453
# Starting from index 1418 with temperature 28.157142639160156
# Starting from index 1419 with temperature 28.171428680419922
# Starting from index 1420 with temperature 28.157142639160156
# Starting from index 1421 with temperature 28.14285659790039
# Starting from index 1422 with temperature 28.114286422729492
# Starting from index 1423 with temperature 28.092857360839844
# Starting from index 1424 with temperature 28.08571434020996
# Starting from index 1425 with temperature 28.071428298950195
# Starting from index 1426 with temperature 28.05714225769043
# Starting from index 1427 with temperature 28.02857208251953
# Starting from index 1428 with temperature 28.007143020629883
# Starting from index 1429 with temperature 27.985713958740234
# Starting from index 1430 with temperature 27.985713958740234
# Starting from index 1431 with temperature 27.97857093811035
# Starting from index 1432 with temperature 27.97142791748047
# Starting from index 1433 with temperature 27.957143783569336
# Starting from index 1434 with temperature 27.91428565979004
# Starting from index 1435 with temperature 27.91428565979004
# Starting from index 1436 with temperature 27.89285659790039
# Starting from index 1437 with temperature 27.871429443359375
# Starting from index 1438 with temperature 27.871429443359375
# Starting from index 1439 with temperature 27.85714340209961
# Starting from index 1440 with temperature 27.85714340209961
# Starting from index 1441 with temperature 27.828571319580078
# Starting from index 1442 with temperature 27.814285278320312
# Starting from index 1443 with temperature 27.828571319580078
# Starting from index 1444 with temperature 27.814285278320312
# Starting from index 1445 with temperature 27.785715103149414
# Starting from index 1446 with temperature 27.785715103149414
# Starting from index 1447 with temperature 27.77142906188965
# Starting from index 1448 with temperature 27.77142906188965
# Starting from index 1449 with temperature 27.757143020629883
# Starting from index 1450 with temperature 27.77142906188965
# Starting from index 1451 with temperature 27.757143020629883
# Starting from index 1452 with temperature 27.742856979370117
# Starting from index 1453 with temperature 27.742856979370117
# Starting from index 1454 with temperature 27.72857093811035
# Starting from index 1455 with temperature 27.742856979370117
# Starting from index 1456 with temperature 27.714284896850586
# Starting from index 1457 with temperature 27.72857093811035
# Starting from index 1458 with temperature 27.685714721679688
# Starting from index 1459 with temperature 27.707143783569336
# Starting from index 1460 with temperature 27.685714721679688
# Starting from index 1461 with temperature 27.69285774230957
# Starting from index 1462 with temperature 27.671428680419922
# Starting from index 1463 with temperature 27.671428680419922
# Starting from index 1464 with temperature 27.671428680419922
# Starting from index 1465 with temperature 27.671428680419922
# Starting from index 1466 with temperature 27.671428680419922
# Starting from index 1467 with temperature 27.671428680419922
# Starting from index 1468 with temperature 27.657142639160156
# Starting from index 1469 with temperature 27.657142639160156
# Starting from index 1470 with temperature 27.657142639160156
# Starting from index 1471 with temperature 27.657142639160156
# Starting from index 1472 with temperature 27.628570556640625
# Starting from index 1473 with temperature 27.64285659790039
# Starting from index 1474 with temperature 27.614286422729492
# Starting from index 1475 with temperature 27.614286422729492
# Starting from index 1476 with temperature 27.58571434020996
# Starting from index 1477 with temperature 27.600000381469727
# Starting from index 1478 with temperature 27.571428298950195
# Starting from index 1479 with temperature 27.571428298950195
# Starting from index 1480 with temperature 27.571428298950195
# Starting from index 1481 with temperature 27.58571434020996
# Starting from index 1482 with temperature 27.571428298950195
# Starting from index 1483 with temperature 27.55714225769043
# Starting from index 1484 with temperature 27.55714225769043
# Starting from index 1485 with temperature 27.571428298950195
# Starting from index 1486 with temperature 27.55714225769043
# Starting from index 1487 with temperature 27.55714225769043
# Starting from index 1488 with temperature 27.55714225769043
# Starting from index 1489 with temperature 27.55714225769043
# Starting from index 1490 with temperature 27.542856216430664
# Starting from index 1491 with temperature 27.571428298950195
# Starting from index 1492 with temperature 27.55714225769043
# Starting from index 1493 with temperature 27.52857208251953
# Starting from index 1494 with temperature 27.55714225769043
# Starting from index 1495 with temperature 27.542856216430664
# Starting from index 1496 with temperature 27.52857208251953
# Starting from index 1497 with temperature 27.542856216430664
# Starting from index 1498 with temperature 27.52857208251953
# Starting from index 1499 with temperature 27.52857208251953
# Starting from index 1500 with temperature 27.52857208251953
# Starting from index 1501 with temperature 27.5
# Starting from index 1502 with temperature 27.514286041259766
# Starting from index 1503 with temperature 27.5
# Starting from index 1504 with temperature 27.5
# Starting from index 1505 with temperature 27.5
# Starting from index 1507 with temperature 27.5
# Best Path: [1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685 ...
# Minimum Cost: tensor(-3221.2344, device='cuda:0')
# Time Taken (in minutes): 4575.45min to reach from 28.0 to 22.0
