# %%
import json
import pandas as pd
import numpy as np

Sensor_readings = pd.read_json('data/json/W512.w512_readings (1).json')
Aircon_Data = pd.read_json('data/json/W512.w512_aircon_status (1).json')
Weather_readings = pd.read_json('data/json/user.weather_data (1).json')

def convert_AirconData(data):
    records = []
    
    for index, row in data.iterrows():
        # Parse FC_FullStatus_Readings if it's a string representation of a dictionary
        if isinstance(row['FC_FullStatus_Readings'], str):
            fc_readings = ast.literal_eval(row['FC_FullStatus_Readings'])
        else:
            fc_readings = row['FC_FullStatus_Readings']


        try:
            combined_datetime = pd.to_datetime(f"{row['date']} {row['time']}")
            formatted_datetime = pd.to_datetime(combined_datetime.strftime("%Y-%m-%d %H:%M:%S"))

        except Exception as e:
            print(f"Error combining datetime for row {index}: {e}")
            combined_datetime = None
            formatted_datetime = None

        
        # Create a record with base information
        record = {
            'Datetime': formatted_datetime
        }
        
        # Add each FC Unit's details as separate columns
        for unit, unit_data in fc_readings.items():
            record[f'{unit}_Status'] = unit_data['Status']
            record[f'{unit}_Fan_Status'] = unit_data['Fan_Status']
            record[f'{unit}_Set_Point'] = unit_data['Set_Point']
            record[f'{unit}_Operation_Mode'] = unit_data['Operation_Mode']
        
        records.append(record)
    
    # Create DataFrame
    df = pd.DataFrame(records)
    return df


def convert_sensorReadings(data):
    records = []
    
    # List of keys to exclude from Lorawan_Readings
    include_keys_1 = ["24E124725E285123", "24E124725E331695","24E124725E331744",
                      "24E124725E332483","24E124725E290348","24E124725E331733","24E124725E286745"]#"24E124136D316361" is suppiosed to be outdoor but it is not outdoor yet
    include_keys_2 = ["Sensor_1","Sensor_3","Sensor_6"]
    
    for index, row in data.iterrows():
        # Parse Energy_Readings if it's a string representation of a dictionary
        if isinstance(row['Energy_Readings'], str):
            Energy_readings = ast.literal_eval(row['Energy_Readings'])
        else:
            Energy_readings = row['Energy_Readings']
            
        # Parse Lorawan_Readings if it's a string representation of a dictionary
        if isinstance(row['Lorawan_Readings'], str):
            Lorawan_Readings = ast.literal_eval(row['Lorawan_Readings'])
        else:
            Lorawan_Readings = row['Lorawan_Readings']

        try:
            # Combine the date and time columns to create a datetime object
            combined_datetime = pd.to_datetime(f"{row['date']} {row['time']}")
            formatted_datetime = pd.to_datetime(combined_datetime.strftime("%Y-%m-%d %H:%M:%S"))
        except Exception as e:
            print(f"Error combining datetime for row {index}: {e}")
            formatted_datetime = None

        # Create a record with base information
        record = {
            'Datetime': formatted_datetime
        }
        
        # Add each Energy sensor's details as separate columns
        for unit, unit_data in Energy_readings.items():
            if unit not in include_keys_2:
                continue
                
            record[f'{unit}_Current'] = unit_data['Current']
            record[f'{unit}_Energy'] = unit_data['Energy']
            record[f'{unit}_Power'] = unit_data['Power']
        
        # Add each Lorawan device's details as separate columns
        for unit, unit_data in Lorawan_Readings.items():
            if unit not in include_keys_1:
                continue
            record[f'{unit}_Humidity'] = unit_data.get('humidity', None)
            record[f'{unit}_Temperature'] = unit_data.get('temperature', None)

            co2_value = unit_data.get('co2', None)
            if co2_value is not None:
                record[f'{unit}_CO2'] = co2_value

        # Append the record to the list of records
        records.append(record)
    df=pd.DataFrame(records)
    return df


def convert_weatherData(data):
    records = []
    for index, row in data.iterrows():
        # Parse Energy_Readings if it's a string representation of a dictionary
        if isinstance(row['result'], str):
            weather_results = ast.literal_eval(row['result'])
        else:
            weather_results = row['result']
            
        try:
            combined_datetime = pd.to_datetime(f"{row['date']} {row['time']}")
            formatted_datetime = pd.to_datetime(combined_datetime.strftime("%Y-%m-%d %H:%M:%S"))
        except Exception as e:
            print(f"Error combining datetime for row {index}: {e}")
            formatted_datetime = None

        record = {
            'Datetime': formatted_datetime
        }  

        record['weather_status'] = weather_results['weather_status']
        record['weather_temp'] = weather_results['weather_temp']
        record['weather_humid'] = weather_results['weather_humidity']
            
        records.append(record)
    df=pd.DataFrame(records)
    return df



Aircon_data_df = convert_AirconData(Aircon_Data)
Aircon_data_df = Aircon_data_df[3194:]
Sensor_readings_df = convert_sensorReadings(Sensor_readings)
Sensor_readings_df = Sensor_readings_df.interpolate(method='linear')
weather_readings_df = convert_weatherData(Weather_readings)

# Merge Aircon data with Sensor readings using merge_asof
merged_df = pd.merge_asof(Aircon_data_df, Sensor_readings_df, on='Datetime', direction='nearest')

# Now, merge the Weather readings with the previous result using merge_asof
merged_df = pd.merge_asof(merged_df, weather_readings_df, on='Datetime', direction='nearest')


merged_df['total_energy'] = (
    merged_df['Sensor_1_Energy'] +
    merged_df['Sensor_3_Energy'] +
    merged_df['Sensor_6_Energy']
)

merged_df['total_power'] = (
    merged_df['Sensor_1_Power'] +
    merged_df['Sensor_3_Power'] +
    merged_df['Sensor_6_Power']
)

merged_df['total_current'] = (
    merged_df['Sensor_1_Current'] +
    merged_df['Sensor_3_Current'] +
    merged_df['Sensor_6_Current']
)

temperature_col = [
    col for col in merged_df.columns 
    if "24e124" in col.lower() and "temperature" in col.lower()
]
humidity_col = [
    col for col in merged_df.columns 
    if "24e124" in col.lower() and "humidity" in col.lower()
]
co2_col = [
    col for col in merged_df.columns 
    if "24e124" in col.lower() and "co2" in col.lower()
]

merged_df['avg_temperature'] = merged_df[temperature_col].mean(axis=1)
merged_df['avg_humidity'] = merged_df[humidity_col].mean(axis=1)
merged_df['avg_co2'] = merged_df[co2_col].mean(axis=1)

# merged_df['future_timestamp'] = merged_df['Datetime'] + pd.Timedelta(minutes=30)

# merged_df['target_temperature'] = pd.merge_asof(
#     merged_df[['future_timestamp']].rename(columns={'future_timestamp': 'Datetime'}),
#     merged_df[['Datetime', 'avg_temperature']],
#     on='Datetime',
#     direction='nearest'
# )['avg_temperature']

# merged_df['target_humidity'] = pd.merge_asof(
#     merged_df[['future_timestamp']].rename(columns={'future_timestamp': 'Datetime'}),
#     merged_df[['Datetime', 'avg_humidity']],
#     on='Datetime',
#     direction='nearest'
# )['avg_humidity']

# merged_df['future_energy'] = pd.merge_asof(
#     merged_df[['future_timestamp']].rename(columns={'future_timestamp': 'Datetime'}),
#     merged_df[['Datetime', 'total_energy']],
#     on='Datetime',
#     direction='nearest'
# )['total_energy']

# merged_df['energy_difference'] = merged_df['future_energy'] - merged_df['total_energy']


dropped_col = [
    col for col in merged_df.columns
    if "24e124" in col.lower()
]
dropped_col_sensor = [
    col for col in merged_df.columns
    if "sensor" in col.lower()
]

columns_to_drop = dropped_col + dropped_col_sensor
merged_df.drop(columns=columns_to_drop, axis=1, inplace=True)



merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2438 entries, 0 to 2437
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Datetime                  2438 non-null   datetime64[ns]
#  1   FC_Unit_1_Status          2438 non-null   object
#  2   FC_Unit_1_Fan_Status      2438 non-null   object
#  3   FC_Unit_1_Set_Point       2438 non-null   float64
#  4   FC_Unit_1_Operation_Mode  2438 non-null   object
#  5   FC_Unit_2_Status          2438 non-null   object
#  6   FC_Unit_2_Fan_Status      2438 non-null   object
#  7   FC_Unit_2_Set_Point       2438 non-null   float64
#  8   FC_Unit_2_Operation_Mode  2438 non-null   object
#  9   FC_Unit_3_Status          2438 non-null   object
#  10  FC_Unit_3_Fan_Status      2438 non-null   object
#  11  FC_Unit_3_Set_Point       2438 non-null   float64
#  12  FC_Unit_3_Operation_Mode  2438 non-null   object
#  13  FC_Unit_4_Status          2438 non-null   object
#  14  FC_Unit_4_Fan_Status      2438 non-null   object
#  15  FC_Unit_4_Set_Point       2438 non-null   float64
#  16  FC_Unit_4_Operation_Mode  2438 non-null   object
#  17  FC_Unit_5_Status          2438 non-null   object
#  18  FC_Unit_5_Fan_Status      2438 non-null   object
#  19  FC_Unit_5_Set_Point       2438 non-null   float64
#  20  FC_Unit_5_Operation_Mode  2438 non-null   object
#  21  FC_Unit_6_Status          2438 non-null   object
#  22  FC_Unit_6_Fan_Status      2438 non-null   object
#  23  FC_Unit_6_Set_Point       2438 non-null   float64
#  24  FC_Unit_6_Operation_Mode  2438 non-null   object
#  25  FC_Unit_7_Status          2438 non-null   object
#  26  FC_Unit_7_Fan_Status      2438 non-null   object
#  27  FC_Unit_7_Set_Point       2438 non-null   float64
#  28  FC_Unit_7_Operation_Mode  2438 non-null   object
#  29  FC_Unit_8_Status          2438 non-null   object
#  30  FC_Unit_8_Fan_Status      2438 non-null   object
#  31  FC_Unit_8_Set_Point       2438 non-null   float64
#  32  FC_Unit_8_Operation_Mode  2438 non-null   object
#  33  weather_status            2438 non-null   object
#  34  weather_temp              2438 non-null   float64
#  35  weather_humid             2438 non-null   int64
#  36  total_energy              2438 non-null   float64
#  37  total_power               2438 non-null   float64
#  38  total_current             2438 non-null   float64
#  39  avg_temperature           2438 non-null   float64
#  40  avg_humidity              2438 non-null   float64
#  41  avg_co2                   2438 non-null   float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(25)
# memory usage: 800.1+ KB

# %%
from tqdm import tqdm

min_energy = merged_df['total_energy'].min()
max_energy = merged_df['total_energy'].max()
min_temp = merged_df['avg_temperature'].min()
max_temp = merged_df['avg_temperature'].max()

energy_weight = 0.5
temp_weight = 0.5

# Initialize variables
current_temperature = 22
target_temperature = 24
best_path = []
min_cost = float('inf')
best_cost, best_path = float('inf'), []


# Memoization dictionary
memo = {}


def calculate_differences(row1, row2):
    energy_diff = (abs(row1['total_energy'] - row2['total_energy']) - min_energy) / (max_energy - min_energy)
    temp_diff = (abs((row1['avg_temperature'] + row2['avg_temperature']) / 2 - target_temperature) - min_temp) / (max_temp - min_temp)
    return energy_diff, temp_diff



def find_best_pathway(current_row_index, current_temp, path, total_cost):
    # Use a tuple of (current_row_index, current_temp) as the key for memoization
    key = (current_row_index, tuple(path))
    if key in memo:
        return memo[key]

    # Base case
    if abs(current_temp - target_temperature) < 0.3:
        return total_cost, path[:]

    best_cost = float('inf')
    best_path = None

    for next_row_index in range(current_row_index + 1, len(merged_df)):
        next_row = merged_df.iloc[next_row_index]
        energy_diff, temp_diff = calculate_differences(merged_df.iloc[current_row_index], next_row)
        cost = energy_diff * energy_weight + temp_diff * temp_weight

        if total_cost + cost >= min_cost:
            continue

        # Recursive call
        new_cost, new_path = find_best_pathway(
            next_row_index, 
            next_row['avg_temperature'], 
            path + [next_row_index], 
            total_cost + cost
        )

        if new_cost < best_cost:
            best_cost = new_cost
            best_path = new_path

    # Store result in memo
    memo[key] = (best_cost, best_path)
    return memo[key]


for start_index, row in tqdm(merged_df.iterrows(), total=len(merged_df), desc="Exploring paths"):
    if abs(row['avg_temperature'] - current_temperature) <= 0.5:
        cost, path = find_best_pathway(start_index, row['avg_temperature'], [start_index], 0)
        if cost < best_cost:
            best_cost = cost
            best_path = path

# Output the result
if best_path:
    print("Best Path:", best_path)
    print("Minimum Cost:", best_cost)
else:
    print("No valid pathway found.")

# %%
import torch

# Convert DataFrame columns to PyTorch tensors
device = 'cuda' if torch.cuda.is_available() else 'cpu'

energy = torch.tensor(merged_df['total_energy'].values, device=device, dtype=torch.float32)
temperature = torch.tensor(merged_df['avg_temperature'].values, device=device, dtype=torch.float32)

# Convert Datetime column to seconds and move to GPU
datetime_seconds = torch.tensor(
    (merged_df['Datetime'] - merged_df['Datetime'].min()).dt.total_seconds().values,
    device=device,
    dtype=torch.float32
)

# Precompute min and max for normalization
min_energy = energy.min()
max_energy = energy.max()
min_temp = temperature.min()
max_temp = temperature.max()
min_time = datetime_seconds.min()
max_time = datetime_seconds.max()

# Weights for the cost function
energy_weight = 0.3
temp_weight = 0.3
time_weight = 0.4

#this is where you edit your variables
current_temperature = 25.0
target_temperature = 22.0
best_path = []
min_cost = float('inf')

# Memoization dictionary
memo = {}


def calculate_differences_gpu(row1_energy, row1_temp, row1_time, row2_energy, row2_temp, row2_time):
    # Calculate energy and temperature differences
    energy_diff = (torch.abs(row1_energy - row2_energy) - min_energy) / (max_energy - min_energy)
    temp_diff = (torch.abs((row1_temp + row2_temp) / 2 - target_temperature) - min_temp) / (max_temp - min_temp)
    # Calculate normalized time difference
    time_diff = (torch.abs(row1_time - row2_time) - min_time) / (max_time - min_time)
    return energy_diff, temp_diff, time_diff


def find_best_pathway(current_row_index, current_temp, path, total_cost, time_taken):
    global min_cost, best_path

    # Memoization key
    key = (current_row_index, tuple(path))
    if key in memo:
        return memo[key]

    # Base case: Target temperature reached
    if abs(current_temp - target_temperature) < 0.3:
        if total_cost < min_cost:
            min_cost = total_cost
            best_path = path[:]
        return total_cost, path[:], time_taken

    best_cost = float('inf')
    best_path_local = None

    for next_row_index in range(current_row_index + 1, len(energy)):
        # Calculate differences using tensors
        energy_diff, temp_diff, time_diff = calculate_differences_gpu(
            energy[current_row_index],
            temperature[current_row_index],
            datetime_seconds[current_row_index],
            energy[next_row_index],
            temperature[next_row_index],
            datetime_seconds[next_row_index]
        )

        # Compute cost
        cost = energy_diff * energy_weight + temp_diff * temp_weight + time_diff * time_weight

        # Pruning condition
        if total_cost + cost >= min_cost:
            continue

        # Recursive call
        new_cost, new_path, new_time_taken = find_best_pathway(
            next_row_index,
            temperature[next_row_index].item(),
            path + [next_row_index],
            total_cost + cost,
            time_taken + (datetime_seconds[next_row_index] - datetime_seconds[current_row_index]).item()
        )

        # Update best cost and path
        if new_cost < best_cost:
            best_cost = new_cost
            best_path_local = new_path

    # Store result in memo
    memo[key] = (best_cost, best_path_local, time_taken)
    return memo[key]


# Start the backtracking process
for start_index in range(len(energy)):
    if abs(temperature[start_index].item() - current_temperature) <= 0.5:
        print(f"Starting backtracking from index {start_index} with temperature {temperature[start_index].item()}")
        find_best_pathway(start_index, temperature[start_index].item(), [start_index], 0, 0)

# Output the result


fcunit_col = [
    col for col in merged_df.columns 
    if "fc_unit" in col.lower()
]
if best_path:
    print("Best Path:", best_path)
    print("Minimum Cost:", min_cost)
    
    # Convert time taken to minutes
    time_taken_in_minutes = sum([datetime_seconds[best_path[i]] - datetime_seconds[best_path[i-1]] for i in range(1, len(best_path))]).item() / 60
    print(f"Time Taken (in minutes): {time_taken_in_minutes:.2f}min to go from {current_temperature} to {target_temperature}")

    best_path_rows = merged_df.iloc[best_path][fcunit_col+['avg_temperature']]
    
    best_path_rows.to_csv(f'{current_temperature}_to_{target_temperature}.csv')
else:
    print("No valid pathway found.")
# Out:
# Starting backtracking from index 8 with temperature 24.657142639160156
# Starting backtracking from index 9 with temperature 24.842857360839844
# Starting backtracking from index 10 with temperature 25.0
# Starting backtracking from index 11 with temperature 25.14285659790039
# Starting backtracking from index 52 with temperature 24.5
# Starting backtracking from index 53 with temperature 24.614286422729492
# Starting backtracking from index 54 with temperature 24.685714721679688
# Starting backtracking from index 55 with temperature 24.785715103149414
# Starting backtracking from index 56 with temperature 24.842857360839844
# Starting backtracking from index 57 with temperature 24.89285659790039
# Starting backtracking from index 58 with temperature 24.985713958740234
# Starting backtracking from index 59 with temperature 25.035715103149414
# Starting backtracking from index 60 with temperature 25.071428298950195
# Starting backtracking from index 61 with temperature 25.171428680419922
# Starting backtracking from index 62 with temperature 25.185714721679688
# Starting backtracking from index 63 with temperature 25.242856979370117
# Starting backtracking from index 64 with temperature 25.264286041259766
# Starting backtracking from index 65 with temperature 25.314285278320312
# Starting backtracking from index 66 with temperature 25.350000381469727
# Starting backtracking from index 67 with temperature 25.385713577270508
# Starting backtracking from index 68 with temperature 25.44285774230957
# Starting backtracking from index 69 with temperature 25.44285774230957
# Starting backtracking from index 70 with temperature 25.457143783569336
# Starting backtracking from index 71 with temperature 25.5
# Starting backtracking from index 198 with temperature 24.899999618530273
# Starting backtracking from index 294 with temperature 24.55714225769043
# Starting backtracking from index 295 with temperature 24.678571701049805
# Starting backtracking from index 296 with temperature 24.757143020629883
# Starting backtracking from index 297 with temperature 24.904762268066406
# Starting backtracking from index 298 with temperature 24.938095092773438
# Starting backtracking from index 299 with temperature 25.05714225769043
# Starting backtracking from index 300 with temperature 25.135713577270508
# Starting backtracking from index 301 with temperature 25.200000762939453
# Starting backtracking from index 302 with temperature 25.25
# Starting backtracking from index 303 with temperature 25.314285278320312
# Starting backtracking from index 304 with temperature 25.364286422729492
# Starting backtracking from index 305 with temperature 25.428571701049805
# Starting backtracking from index 306 with temperature 25.450000762939453
# Starting backtracking from index 466 with temperature 25.264286041259766
# Starting backtracking from index 467 with temperature 24.757143020629883
# Starting backtracking from index 534 with temperature 24.571428298950195
# Starting backtracking from index 535 with temperature 24.742856979370117
# Starting backtracking from index 536 with temperature 24.957143783569336
# Starting backtracking from index 537 with temperature 25.121429443359375
# Starting backtracking from index 538 with temperature 25.214284896850586
# Starting backtracking from index 539 with temperature 25.200000762939453
# Starting backtracking from index 540 with temperature 24.80714225769043
# Starting backtracking from index 559 with temperature 24.614286422729492
# Starting backtracking from index 560 with temperature 24.735713958740234
# Starting backtracking from index 561 with temperature 24.91428565979004
# Starting backtracking from index 562 with temperature 25.014286041259766
# Starting backtracking from index 563 with temperature 25.14285659790039
# Starting backtracking from index 564 with temperature 25.242856979370117
# Starting backtracking from index 565 with temperature 25.328571319580078
# Starting backtracking from index 566 with temperature 25.44285774230957
# Starting backtracking from index 769 with temperature 25.41428565979004
# Starting backtracking from index 770 with temperature 25.314285278320312
# Starting backtracking from index 771 with temperature 25.171428680419922
# Starting backtracking from index 772 with temperature 25.08571434020996
# Starting backtracking from index 773 with temperature 25.014286041259766
# Starting backtracking from index 774 with temperature 24.950000762939453
# Starting backtracking from index 775 with temperature 24.885713577270508
# Starting backtracking from index 776 with temperature 24.828571319580078
# Starting backtracking from index 777 with temperature 24.842857360839844
# Starting backtracking from index 778 with temperature 24.842857360839844
# Starting backtracking from index 779 with temperature 24.83571434020996
# Starting backtracking from index 780 with temperature 24.86190414428711
# Starting backtracking from index 781 with temperature 24.823808670043945
# Starting backtracking from index 782 with temperature 24.742856979370117
# Starting backtracking from index 783 with temperature 24.72142791748047
# Starting backtracking from index 784 with temperature 24.742856979370117
# Starting backtracking from index 785 with temperature 24.75
# Starting backtracking from index 786 with temperature 24.700000762939453
# Starting backtracking from index 787 with temperature 24.700000762939453
# Starting backtracking from index 788 with temperature 24.714284896850586
# Starting backtracking from index 789 with temperature 24.685714721679688
# Starting backtracking from index 790 with temperature 24.64285659790039
# Starting backtracking from index 791 with temperature 24.64285659790039
# Starting backtracking from index 792 with temperature 24.600000381469727
# Starting backtracking from index 793 with temperature 24.628570556640625
# Starting backtracking from index 794 with temperature 24.628570556640625
# Starting backtracking from index 795 with temperature 24.628570556640625
# Starting backtracking from index 796 with temperature 24.649999618530273
# Starting backtracking from index 797 with temperature 24.671428680419922
# Starting backtracking from index 798 with temperature 24.77142906188965
# Starting backtracking from index 799 with temperature 24.77142906188965
# Starting backtracking from index 800 with temperature 24.742856979370117
# Starting backtracking from index 801 with temperature 24.764286041259766
# Starting backtracking from index 802 with temperature 24.785715103149414
# Starting backtracking from index 803 with temperature 24.85714340209961
# Starting backtracking from index 804 with temperature 24.957143783569336
# Starting backtracking from index 805 with temperature 25.10714340209961
# Starting backtracking from index 806 with temperature 25.14285659790039
# Starting backtracking from index 807 with temperature 25.121429443359375
# Starting backtracking from index 808 with temperature 25.042856216430664
# Starting backtracking from index 809 with temperature 24.97857093811035
# Starting backtracking from index 810 with temperature 24.928571701049805
# Starting backtracking from index 811 with temperature 24.928571701049805
# Starting backtracking from index 812 with temperature 24.864286422729492
# Starting backtracking from index 813 with temperature 24.842857360839844
# Starting backtracking from index 814 with temperature 24.757143020629883
# Starting backtracking from index 815 with temperature 24.77142906188965
# Starting backtracking from index 816 with temperature 24.742856979370117
# Starting backtracking from index 817 with temperature 24.77142906188965
# Starting backtracking from index 818 with temperature 24.72857093811035
# Starting backtracking from index 819 with temperature 24.707143783569336
# Starting backtracking from index 820 with temperature 24.742856979370117
# Starting backtracking from index 821 with temperature 24.714284896850586
# Starting backtracking from index 822 with temperature 24.714284896850586
# Starting backtracking from index 823 with temperature 24.700000762939453
# Starting backtracking from index 824 with temperature 24.657142639160156
# Starting backtracking from index 825 with temperature 24.735713958740234
# Starting backtracking from index 826 with temperature 24.72857093811035
# Starting backtracking from index 827 with temperature 24.764286041259766
# Starting backtracking from index 828 with temperature 24.828571319580078
# Starting backtracking from index 829 with temperature 24.792856216430664
# Starting backtracking from index 830 with temperature 25.0
# Starting backtracking from index 831 with temperature 25.200000762939453
# Starting backtracking from index 832 with temperature 25.435714721679688
# Starting backtracking from index 1534 with temperature 25.342857360839844
# Starting backtracking from index 1535 with temperature 25.135713577270508
# Starting backtracking from index 1536 with temperature 24.97142791748047
# Starting backtracking from index 1537 with temperature 24.814285278320312
# Starting backtracking from index 1538 with temperature 24.685714721679688
# Starting backtracking from index 1539 with temperature 24.58571434020996
# Starting backtracking from index 1600 with temperature 24.60714340209961
# Starting backtracking from index 1601 with temperature 24.864286422729492
# Starting backtracking from index 1602 with temperature 25.08571434020996
# Starting backtracking from index 1603 with temperature 25.264286041259766
# Starting backtracking from index 1604 with temperature 25.44285774230957
# Starting backtracking from index 1780 with temperature 25.30714225769043
# Starting backtracking from index 1781 with temperature 25.08571434020996
# Starting backtracking from index 1782 with temperature 24.885713577270508
# Starting backtracking from index 1783 with temperature 24.885713577270508
# Starting backtracking from index 1784 with temperature 24.885713577270508
# Starting backtracking from index 1785 with temperature 24.885713577270508
# Starting backtracking from index 1786 with temperature 24.72857093811035
# Starting backtracking from index 1787 with temperature 24.792856216430664
# Starting backtracking from index 1788 with temperature 24.785715103149414
# Starting backtracking from index 1789 with temperature 24.58571434020996
# Starting backtracking from index 1967 with temperature 24.5
# Starting backtracking from index 1968 with temperature 24.657142639160156
# Starting backtracking from index 1969 with temperature 24.77857208251953
# Starting backtracking from index 1970 with temperature 24.871429443359375
# Starting backtracking from index 1971 with temperature 24.97857093811035
# Starting backtracking from index 1972 with temperature 25.071428298950195
# Starting backtracking from index 1973 with temperature 25.157142639160156
# Starting backtracking from index 1974 with temperature 25.242856979370117
# Starting backtracking from index 1975 with temperature 25.321428298950195
# Starting backtracking from index 1976 with temperature 25.380952835083008
# Starting backtracking from index 1977 with temperature 25.44761848449707
# Starting backtracking from index 2170 with temperature 25.214284896850586
# Starting backtracking from index 2171 with temperature 24.935714721679688
# Starting backtracking from index 2172 with temperature 24.614286422729492
# Starting backtracking from index 2225 with temperature 24.514286041259766
# Starting backtracking from index 2226 with temperature 24.578571319580078
# Starting backtracking from index 2227 with temperature 24.614286422729492
# Starting backtracking from index 2228 with temperature 24.700000762939453
# Starting backtracking from index 2229 with temperature 24.72857093811035
# Starting backtracking from index 2230 with temperature 24.77857208251953
# Starting backtracking from index 2231 with temperature 24.77857208251953
# Starting backtracking from index 2232 with temperature 24.77857208251953
# Starting backtracking from index 2233 with temperature 24.77857208251953
# Starting backtracking from index 2234 with temperature 24.828571319580078
# Starting backtracking from index 2235 with temperature 24.792856216430664
# Starting backtracking from index 2236 with temperature 24.671428680419922
# Starting backtracking from index 2237 with temperature 24.785715103149414
# Starting backtracking from index 2238 with temperature 25.014286041259766
# Starting backtracking from index 2239 with temperature 25.014286041259766
# Starting backtracking from index 2240 with temperature 25.014286041259766
# Starting backtracking from index 2241 with temperature 25.285715103149414
# Best Path: [8, 9, 10, 11, 12, 13, 14, 15, 17]
# Minimum Cost: tensor(-28.8548, device='cuda:0')
# Time Taken (in minutes): 154.73min to go from 25.0 to 22.0
